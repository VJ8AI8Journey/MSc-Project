# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/1-Introduction/Stock_NeurIPS2018_SB3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading
#
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Task Description](#0)
# * [2. Install Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. A List of Python Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download and Preprocess Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5. Build Market Environment in OpenAI Gym-style](#4)
#     * [5.1. Data Split](#4.1)
#     * [5.3. Environment for Training](#4.2)
# * [6. Train DRL Agents](#5)
# * [7. Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Task Discription

# %% [markdown]
# We train a DRL agent for stock trading. This task is modeled as a Markov Decision Process (MDP), and the objective function is maximizing (expected) cumulative return.
#
# We specify the state-action-reward as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes many features and learns by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 consituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.
#
#
# The data for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Install Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install packages

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. A list of Python packages
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
# %matplotlib inline

from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor
from finrl.meta.data_processors.processor_yahoofinance import YahooFinanceProcessor
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL")

import itertools
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas_datareader/compat/__init__.py:11: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   PANDAS_VERSION = LooseVersion(pd.__version__)
# /usr/local/lib/python3.11/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
from finrl import config
from finrl import config_tickers
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance provides stock data, financial news, financial reports, etc. Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** in FinRL-Meta to fetch data via Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()

# %%
# from config.py, TRAIN_START_DATE is a string
TRAIN_START_DATE
# from config.py, TRAIN_END_DATE is a string
TRAIN_END_DATE
# Out:
# '2020-07-31'

# %%
TRAIN_START_DATE = '2010-01-01'
TRAIN_END_DATE = '2023-10-01'
TRADE_START_DATE = '2023-10-01'
TRADE_END_DATE = '2025-03-01'

# %%
df = YahooDownloader(start_date = TRAIN_START_DATE,
                    end_date = TRADE_END_DATE,
                    ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
# yfp = YahooFinanceProcessor()
# df = yfp.download_data(['AXP', 'AMGN', 'AAPL'], '2010-01-01', '2010-02-01', '1m')
print(df)
# Out:
# YF deprecation warning: set proxy via new config function: yf.set_config(proxy=proxy)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (112073, 8)
# Price         date       close        high         low        open     volume  \
# 0       2010-01-04    6.431897    6.446624    6.382909    6.414466  493729600
# 1       2010-01-04   39.913254   40.016977   39.111116   39.159521    5277400
# 2       2010-01-04   32.637947   32.781516   32.215218   32.550213    6894300
# 3       2010-01-04   43.777550   43.941189   42.702201   43.419101    6186700
# 4       2010-01-04   39.547810   39.980100   38.845337   38.939903    7325600
# ...            ...         ...         ...         ...         ...        ...
# 112068  2025-02-28  469.605164  470.989374  459.243337  461.734915    6146300
# 112069  2025-02-28  362.108612  363.396482  353.123534  354.121876   15857300
# 112070  2025-02-28   41.743721   42.382952   41.269142   42.063338   25197500
# 112071  2025-02-28   10.680000   11.490000   10.480000   10.630000   52407400
# 112072  2025-02-28   98.102753   98.351467   96.670158   97.286971   25451300
#
# Price    tic  day
# 0       AAPL    0
# 1       AMGN    0
# 2        AXP    0
# 3         BA    0
# 4        CAT    0
# ...      ...  ...
# 112068   UNH    4
# 112069     V    4
# 112070    VZ    4
# 112071   WBA    4
# 112072   WMT    4
#
# [112073 rows x 8 columns]

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
df.shape
# Out:
# (112073, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
# Price        date      close       high        low       open     volume  \
# 0      2010-01-04   6.431897   6.446624   6.382909   6.414466  493729600
# 1      2010-01-04  39.913254  40.016977  39.111116  39.159521    5277400
# 2      2010-01-04  32.637947  32.781516  32.215218  32.550213    6894300
# 3      2010-01-04  43.777550  43.941189  42.702201  43.419101    6186700
# 4      2010-01-04  39.547810  39.980100  38.845337  38.939903    7325600
#
# Price   tic  day
# 0      AAPL    0
# 1      AMGN    0
# 2       AXP    0
# 3        BA    0
# 4       CAT    0

# %% [markdown]
# # Part 4: Preprocess Data
# We need to check for missing data and do feature engineering to convert the data point into a state.
# * **Adding technical indicators**. In practical trading, various information needs to be taken into account, such as historical prices, current holding shares, technical indicators, etc. Here, we demonstrate two trend-following technical indicators: MACD and RSI.
# * **Adding turbulence index**. Risk-aversion reflects whether an investor prefers to protect the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the turbulence index that measures extreme fluctuation of asset price.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=True,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3812, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
print(processed)
# Out:
#               date       close        high         low        open     volume  \
# 0       2010-01-04    6.431897    6.446624    6.382909    6.414466  493729600
# 1       2010-01-04   39.913254   40.016977   39.111116   39.159521    5277400
# 2       2010-01-04   32.637947   32.781516   32.215218   32.550213    6894300
# 3       2010-01-04   43.777550   43.941189   42.702201   43.419101    6186700
# 4       2010-01-04   39.547810   39.980100   38.845337   38.939903    7325600
# ...            ...         ...         ...         ...         ...        ...
# 110543  2025-02-27  463.277344  470.040224  459.777246  460.914305    4216800
# 110544  2025-02-27  355.150177  359.712607  351.096911  351.316547    7298100
# 110545  2025-02-27   41.908375   42.053652   41.540332   41.724355   19212300
# 110546  2025-02-27   11.230000   11.850000   11.190000   11.700000   18971100
# 110547  2025-02-27   96.292122   97.535692   95.317160   95.406701   16431500
#
#          tic  day       macd     boll_ub     boll_lb      rsi_30      cci_30  \
# 0       AAPL    0   0.000000    6.453183    6.421731  100.000000   66.666667
# 1       AMGN    0   0.000000    6.453183    6.421731  100.000000   66.666667
# 2        AXP    0   0.000000    6.453183    6.421731  100.000000   66.666667
# 3         BA    0   0.000000    6.453183    6.421731  100.000000   66.666667
# 4        CAT    0   0.000000    6.453183    6.421731  100.000000   66.666667
# ...      ...  ...        ...         ...         ...         ...         ...
# 110543   UNH    3 -17.034844  569.107078  446.572314   38.382776 -151.903836
# 110544     V    3   6.517566  358.089023  340.578998   67.755444   88.725038
# 110545    VZ    3   0.941336   42.709080   37.053399   63.095706  150.380389
# 110546   WBA    3   0.131985   11.640952    9.051048   54.310579   53.021372
# 110547   WMT    3   0.231981  106.617438   92.929794   52.464471  -23.096908
#
#              dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0       100.000000      6.431897      6.431897  20.040001    0.000000
# 1       100.000000     39.913254     39.913254  20.040001    0.000000
# 2       100.000000     32.637947     32.637947  20.040001    0.000000
# 3       100.000000     43.777550     43.777550  20.040001    0.000000
# 4       100.000000     39.547810     39.547810  20.040001    0.000000
# ...            ...           ...           ...        ...         ...
# 110543   54.471929    513.065271    519.223473  21.129999   22.600588
# 110544   51.636477    341.314856    327.031831  21.129999   22.600588
# 110545   34.317303     39.285269     39.082901  21.129999   22.600588
# 110546   21.201057     10.832667     10.250167  21.129999   22.600588
# 110547    9.235219     97.742618     94.994802  21.129999   22.600588
#
# [110548 rows x 18 columns]

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.sort_values(['date','tic'],ignore_index=True).head(10)
# Out:
#          date   tic       close        high         low        open  \
# 0  2010-01-04  AAPL    6.431897    6.446624    6.382909    6.414466
# 1  2010-01-04  AMGN   39.913254   40.016977   39.111116   39.159521
# 2  2010-01-04   AXP   32.637947   32.781516   32.215218   32.550213
# 3  2010-01-04    BA   43.777550   43.941189   42.702201   43.419101
# 4  2010-01-04   CAT   39.547810   39.980100   38.845337   38.939903
# 5  2010-01-04   CRM   18.542521   18.718478   18.386389   18.490477
# 6  2010-01-04  CSCO   16.158167   16.256333   15.713146   15.778591
# 7  2010-01-04   CVX   42.603550   42.678992   42.118565   42.140116
# 8  2010-01-04   DIS   27.475878   28.058466   27.304529   27.844279
# 9  2010-01-04    GS  131.992065  132.884315  129.269552  129.681366
#
#         volume  day  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  \
# 0  493729600.0  0.0   0.0  6.453183  6.421731   100.0  66.666667  100.0
# 1    5277400.0  0.0   0.0  6.453183  6.421731   100.0  66.666667  100.0
# 2    6894300.0  0.0   0.0  6.453183  6.421731   100.0  66.666667  100.0
# 3    6186700.0  0.0   0.0  6.453183  6.421731   100.0  66.666667  100.0
# 4    7325600.0  0.0   0.0  6.453183  6.421731   100.0  66.666667  100.0
# 5    7906000.0  0.0   0.0  6.453183  6.421731   100.0  66.666667  100.0
# 6   59853700.0  0.0   0.0  6.453183  6.421731   100.0  66.666667  100.0
# 7   10173800.0  0.0   0.0  6.453183  6.421731   100.0  66.666667  100.0
# 8   13700400.0  0.0   0.0  6.453183  6.421731   100.0  66.666667  100.0
# 9    9135000.0  0.0   0.0  6.453183  6.421731   100.0  66.666667  100.0
#
#    close_30_sma  close_60_sma        vix  turbulence
# 0      6.431897      6.431897  20.040001         0.0
# 1     39.913254     39.913254  20.040001         0.0
# 2     32.637947     32.637947  20.040001         0.0
# 3     43.777550     43.777550  20.040001         0.0
# 4     39.547810     39.547810  20.040001         0.0
# 5     18.542521     18.542521  20.040001         0.0
# 6     16.158167     16.158167  20.040001         0.0
# 7     42.603550     42.603550  20.040001         0.0
# 8     27.475878     27.475878  20.040001         0.0
# 9    131.992065    131.992065  20.040001         0.0

# %%
mvo_df = processed_full.sort_values(['date','tic'],ignore_index=True)[['date','tic','close']]

# %% [markdown]
# <a id='4'></a>
# # Part 5. Build A Market Environment in OpenAI Gym-style
# The training process involves observing stock price change, taking an action and reward's calculation. By interacting with the market environment, the agent will eventually derive a trading strategy that may maximize (expected) rewards.
#
# Our market environment, based on OpenAI Gym, simulates stock markets with historical market data.

# %% [markdown]
# ## Data Split
# We split the data into training set and testing set as follows:
#
# Training data period: 2009-01-01 to 2020-07-01
#
# Trading data period: 2020-07-01 to 2021-10-31

# %%
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
train_length = len(train)
trade_length = len(trade)
print(train_length)
print(trade_length)
# Out:
# 100311
# 10237

# %%
train.tail()
# Out:
#             date  tic       close        high         low        open  \
# 3458  2023-09-29  UNH  489.152252  494.672547  488.773870  494.643443
# 3458  2023-09-29    V  227.020599  230.001353  226.665278  229.813820
# 3458  2023-09-29   VZ   28.312363   28.609376   28.277419   28.495811
# 3458  2023-09-29  WBA   20.083014   20.254587   18.854915   18.963277
# 3458  2023-09-29  WMT   52.213684   53.258414   51.972087   53.225766
#
#           volume  day      macd     boll_ub     boll_lb     rsi_30  \
# 3458   3006200.0  4.0  4.758835  499.945967  450.959716  55.148650
# 3458   6044200.0  4.0 -3.066164  251.200591  224.032601  41.887464
# 3458  19759400.0  4.0 -0.276669   30.421854   28.184127  41.243781
# 3458  25659100.0  4.0 -1.050146   20.962601   18.592989  36.119167
# 3458  18842400.0  4.0  0.139828   54.153628   52.232612  50.578496
#
#           cci_30      dx_30  close_30_sma  close_60_sma    vix  turbulence
# 3458  128.373625  19.202268    475.052340    477.039842  17.52   57.508204
# 3458 -154.263210  36.909291    238.148426    237.149245  17.52   57.508204
# 3458 -137.570968  33.867434     29.353075     29.363413  17.52   57.508204
# 3458  -53.011609  26.754731     20.958936     23.656806  17.52   57.508204
# 3458  -24.941098  17.468253     52.741926     52.075983  17.52   57.508204

# %%
trade.head()
# Out:
#          date   tic       close        high         low        open  \
# 0  2023-10-02  AAPL  172.259903  172.805189  169.464080  169.751602
# 0  2023-10-02  AMGN  252.198303  254.262779  250.370580  253.524112
# 0  2023-10-02   AXP  145.907867  146.317829  144.531574  144.873201
# 0  2023-10-02    BA  187.830002  192.440002  186.929993  191.470001
# 0  2023-10-02   CAT  263.813934  268.755830  262.376986  264.707179
#
#        volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  52164500.0  0.0 -2.561662  183.575468  165.836040  45.243151  -87.977370
# 0   1912300.0  0.0  3.867166  261.151697  237.536324  59.425490   72.228925
# 0   2657600.0  0.0 -3.052553  160.817399  143.761845  37.445527 -174.732962
# 0   5244700.0  0.0 -8.257769  223.250012  185.200986  32.814602 -138.625438
# 0   1778200.0  0.0 -0.882071  278.116221  260.880932  51.346799  -69.196869
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  26.128867    176.566327    181.009779  17.610001    34.48058
# 0  31.542849    247.539639    237.412814  17.610001    34.48058
# 0  36.526656    153.348369    158.819425  17.610001    34.48058
# 0  66.417390    211.389666    218.712000  17.610001    34.48058
# 0   1.038297    269.065551    264.989035  17.610001    34.48058

# %%
INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for Training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**. Users are also encouraged to try **ElegantRL** and **Ray RLlib**.
# * FinRL includes fine-tuned standard DRL algorithms, such as DQN, DDPG, Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
agent = DRLAgent(env = env_train)

if_using_a2c = True
if_using_ddpg = True
if_using_ppo = True
if_using_td3 = True
if_using_sac = True

# %% [markdown]
# ### Agent Training: algorithm (PPO)

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to results/ppo
# /usr/local/lib/python3.11/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
trained_ppo = agent.train_model(model=model_ppo,
                             tb_log_name='ppo',
                             total_timesteps=50000) if if_using_ppo else None
# Out:
# -----------------------------------
# | time/              |            |
# |    fps             | 106        |
# |    iterations      | 1          |
# |    time_elapsed    | 19         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.598458   |
# |    reward_max      | 7.5978494  |
# |    reward_mean     | 0.09067049 |
# |    reward_min      | -13.029407 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 2           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014696786 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | -0.00176    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.79        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0198     |
# |    reward               | -0.18570508 |
# |    reward_max           | 27.896402   |
# |    reward_mean          | 0.10676504  |
# |    reward_min           | -39.06427   |
# |    std                  | 1           |
# |    value_loss           | 11.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 3           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017988743 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.00489     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 34.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0206     |
# |    reward               | 1.764696    |
# |    reward_max           | 24.262213   |
# |    reward_mean          | 0.112387985 |
# |    reward_min           | -30.575317  |
# |    std                  | 1           |
# |    value_loss           | 51.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 4           |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017501883 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.000289    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0199     |
# |    reward               | 0.89843273  |
# |    reward_max           | 10.95269    |
# |    reward_mean          | 0.06640627  |
# |    reward_min           | -10.125174  |
# |    std                  | 1           |
# |    value_loss           | 50.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 5           |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013840077 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0469     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.58        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.024      |
# |    reward               | -1.6876012  |
# |    reward_max           | 25.564812   |
# |    reward_mean          | 0.0951493   |
# |    reward_min           | -33.131626  |
# |    std                  | 1           |
# |    value_loss           | 12.3        |
# -----------------------------------------
# day: 2956, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 4649562.12
# total_reward: 3649562.12
# total_cost: 382901.84
# total_trades: 82353
# Sharpe: 0.865
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 6           |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015203544 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.012       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 18.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0172     |
# |    reward               | 0.26013863  |
# |    reward_max           | 29.162766   |
# |    reward_mean          | 0.13989168  |
# |    reward_min           | -37.42057   |
# |    std                  | 1.01        |
# |    value_loss           | 42.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 7           |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.022036238 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.00605    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22.8        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0137     |
# |    reward               | 3.069528    |
# |    reward_max           | 16.559002   |
# |    reward_mean          | 0.13319248  |
# |    reward_min           | -14.4258    |
# |    std                  | 1.01        |
# |    value_loss           | 71.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 8           |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.022186872 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | 0.0126      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.09        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0195     |
# |    reward               | -2.1270013  |
# |    reward_max           | 31.412384   |
# |    reward_mean          | 0.111219645 |
# |    reward_min           | -42.518845  |
# |    std                  | 1.01        |
# |    value_loss           | 28.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 9           |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.019627888 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | 0.0124      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 37.2        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0162     |
# |    reward               | 1.1380596   |
# |    reward_max           | 28.541084   |
# |    reward_mean          | 0.14632282  |
# |    reward_min           | -42.398712  |
# |    std                  | 1.01        |
# |    value_loss           | 77.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 10          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.030549726 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | 0.000414    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 52          |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0148     |
# |    reward               | -0.78912055 |
# |    reward_max           | 29.33362    |
# |    reward_mean          | 0.13199694  |
# |    reward_min           | -37.06535   |
# |    std                  | 1.01        |
# |    value_loss           | 67.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 104         |
# |    iterations           | 11          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.030013792 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | 0.00168     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 29.7        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0138     |
# |    reward               | -0.31606317 |
# |    reward_max           | 15.945143   |
# |    reward_mean          | 0.08867398  |
# |    reward_min           | -11.016172  |
# |    std                  | 1.02        |
# |    value_loss           | 65.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 12          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.023350282 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | 0.0211      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.8        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.016      |
# |    reward               | 0.8402303   |
# |    reward_max           | 31.236979   |
# |    reward_mean          | 0.15631461  |
# |    reward_min           | -39.617092  |
# |    std                  | 1.02        |
# |    value_loss           | 20.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 13           |
# |    time_elapsed         | 255          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.02374858   |
# |    clip_fraction        | 0.209        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.6        |
# |    explained_variance   | -0.00501     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 35.6         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0143      |
# |    reward               | -0.060616862 |
# |    reward_max           | 22.469456    |
# |    reward_mean          | 0.14228939   |
# |    reward_min           | -36.763115   |
# |    std                  | 1.02         |
# |    value_loss           | 87.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 14          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.024655621 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | -0.012      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 20          |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0137     |
# |    reward               | 5.2708135   |
# |    reward_max           | 8.563884    |
# |    reward_mean          | 0.1126739   |
# |    reward_min           | -15.114902  |
# |    std                  | 1.02        |
# |    value_loss           | 62.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 103        |
# |    iterations           | 15         |
# |    time_elapsed         | 295        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.02323313 |
# |    clip_fraction        | 0.268      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.8      |
# |    explained_variance   | 0.0874     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 7.67       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0154    |
# |    reward               | 0.57719415 |
# |    reward_max           | 27.17664   |
# |    reward_mean          | 0.09867418 |
# |    reward_min           | -39.125874 |
# |    std                  | 1.02       |
# |    value_loss           | 16         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 16          |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.025760267 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.0376      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 50.4        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0146     |
# |    reward               | -0.2384136  |
# |    reward_max           | 24.309465   |
# |    reward_mean          | 0.13130334  |
# |    reward_min           | -36.72041   |
# |    std                  | 1.03        |
# |    value_loss           | 86          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 17          |
# |    time_elapsed         | 335         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.026233092 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | 0.0425      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 25.8        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00937    |
# |    reward               | -2.2586854  |
# |    reward_max           | 12.756389   |
# |    reward_mean          | 0.08787705  |
# |    reward_min           | -12.492719  |
# |    std                  | 1.03        |
# |    value_loss           | 80.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 18          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.026312027 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | -0.077      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.2        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00655    |
# |    reward               | -4.212883   |
# |    reward_max           | 20.795347   |
# |    reward_mean          | 0.046882056 |
# |    reward_min           | -33.266487  |
# |    std                  | 1.03        |
# |    value_loss           | 17.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 19          |
# |    time_elapsed         | 375         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.024770297 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.00227     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 28.3        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00963    |
# |    reward               | -0.395033   |
# |    reward_max           | 23.583803   |
# |    reward_mean          | 0.11072063  |
# |    reward_min           | -37.024956  |
# |    std                  | 1.03        |
# |    value_loss           | 56.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 103        |
# |    iterations           | 20         |
# |    time_elapsed         | 395        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01783576 |
# |    clip_fraction        | 0.201      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.1      |
# |    explained_variance   | 0.026      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 29.1       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0151    |
# |    reward               | -0.5247054 |
# |    reward_max           | 18.218996  |
# |    reward_mean          | 0.16486388 |
# |    reward_min           | -14.540109 |
# |    std                  | 1.03       |
# |    value_loss           | 46.7       |
# ----------------------------------------
# day: 2956, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 6003081.54
# total_reward: 5003081.54
# total_cost: 375186.56
# total_trades: 81390
# Sharpe: 0.935
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 21          |
# |    time_elapsed         | 414         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.026328929 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.0424      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 16.2        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0106     |
# |    reward               | -0.28541183 |
# |    reward_max           | 33.5054     |
# |    reward_mean          | 0.11497492  |
# |    reward_min           | -50.671867  |
# |    std                  | 1.04        |
# |    value_loss           | 35          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 103          |
# |    iterations           | 22           |
# |    time_elapsed         | 434          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.017736992  |
# |    clip_fraction        | 0.173        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -42.2        |
# |    explained_variance   | 0.0315       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 62.5         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0165      |
# |    reward               | -0.035384834 |
# |    reward_max           | 19.647093    |
# |    reward_mean          | 0.09328406   |
# |    reward_min           | -33.852512   |
# |    std                  | 1.04         |
# |    value_loss           | 104          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 103        |
# |    iterations           | 23         |
# |    time_elapsed         | 453        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01802855 |
# |    clip_fraction        | 0.175      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.2      |
# |    explained_variance   | -0.0302    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 32.2       |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.015     |
# |    reward               | 1.3596975  |
# |    reward_max           | 28.025812  |
# |    reward_mean          | 0.16559438 |
# |    reward_min           | -49.94557  |
# |    std                  | 1.04       |
# |    value_loss           | 57         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 24          |
# |    time_elapsed         | 473         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.031511024 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.3       |
# |    explained_variance   | 0.00297     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21.6        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0118     |
# |    reward               | 1.0324053   |
# |    reward_max           | 17.128117   |
# |    reward_mean          | 0.11768017  |
# |    reward_min           | -14.296248  |
# |    std                  | 1.04        |
# |    value_loss           | 90.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 103        |
# |    iterations           | 25         |
# |    time_elapsed         | 494        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.03082046 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.3      |
# |    explained_variance   | 0.0489     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 14         |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0166    |
# |    reward               | 1.2391791  |
# |    reward_max           | 33.044456  |
# |    reward_mean          | 0.18864515 |
# |    reward_min           | -54.80977  |
# |    std                  | 1.04       |
# |    value_loss           | 25.9       |
# ----------------------------------------

# %% [markdown]
# ## In-sample Performance
#
# Assume that the initial capital is $1,000,000.

# %% [markdown]
# ### Set turbulence threshold
# Set the turbulence threshold to be greater than the maximum of insample turbulence data. If current turbulence index is greater than the threshold, then we assume that the current market is volatile

# %%
data_risk_indicator = processed_full[(processed_full.date<TRAIN_END_DATE) & (processed_full.date>=TRAIN_START_DATE)]
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])

# %%
insample_risk_indicator.vix.describe()
# Out:
# count    3459.000000
# mean       18.633854
# std         7.150486
# min         9.140000
# 25%        13.705000
# 50%        16.870001
# 75%        21.570000
# max        82.690002
# Name: vix, dtype: float64

# %%
insample_risk_indicator.vix.quantile(0.996)
# Out:
# np.float64(54.89679946899445)

# %%
insample_risk_indicator.turbulence.describe()
# Out:
# count    3459.000000
# mean       34.754935
# std        42.349232
# min         0.000000
# 25%        15.118185
# 50%        24.215285
# 75%        39.726675
# max       652.504732
# Name: turbulence, dtype: float64

# %%
insample_risk_indicator.turbulence.quantile(0.996)
# Out:
# np.float64(263.5039659880582)

# %% [markdown]
# ### Trading (Out-of-sample Performance)
#
# We update periodically in order to take full advantage of the data, e.g., retrain quarterly, monthly or weekly. We also tune the parameters along the way, in this notebook we use the in-sample data from 2009-01 to 2020-07 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
trade.head()
# Out:
#          date   tic       close        high         low        open  \
# 0  2023-10-02  AAPL  172.259903  172.805189  169.464080  169.751602
# 0  2023-10-02  AMGN  252.198303  254.262779  250.370580  253.524112
# 0  2023-10-02   AXP  145.907867  146.317829  144.531574  144.873201
# 0  2023-10-02    BA  187.830002  192.440002  186.929993  191.470001
# 0  2023-10-02   CAT  263.813934  268.755830  262.376986  264.707179
#
#        volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  52164500.0  0.0 -2.561662  183.575468  165.836040  45.243151  -87.977370
# 0   1912300.0  0.0  3.867166  261.151697  237.536324  59.425490   72.228925
# 0   2657600.0  0.0 -3.052553  160.817399  143.761845  37.445527 -174.732962
# 0   5244700.0  0.0 -8.257769  223.250012  185.200986  32.814602 -138.625438
# 0   1778200.0  0.0 -0.882071  278.116221  260.880932  51.346799  -69.196869
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  26.128867    176.566327    181.009779  17.610001    34.48058
# 0  31.542849    247.539639    237.412814  17.610001    34.48058
# 0  36.526656    153.348369    158.819425  17.610001    34.48058
# 0  66.417390    211.389666    218.712000  17.610001    34.48058
# 0   1.038297    269.065551    264.989035  17.610001    34.48058

# %%
trained_moedl = trained_ppo
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_moedl,
    environment = e_trade_gym)
# Out:
# hit end!

# %% [markdown]
# <a id='7'></a>
# # Part 6.5: Mean Variance Optimization

# %% [markdown]
# Mean Variance optimization is a very classic strategy in portfolio management. Here, we go through the whole process to do the mean variance optimization and add it as a baseline to compare.
#
# First, process dataframe to the form for MVO weight calculation.

# %%
def process_df_for_mvo(df):
  df = df.sort_values(['date','tic'],ignore_index=True)[['date','tic','close']]
  fst = df
  fst = fst.iloc[0:stock_dimension, :]
  tic = fst['tic'].tolist()

  mvo = pd.DataFrame()

  for k in range(len(tic)):
    mvo[tic[k]] = 0

  for i in range(df.shape[0]//stock_dimension):
    n = df
    n = n.iloc[i * stock_dimension:(i+1) * stock_dimension, :]
    date = n['date'][i*stock_dimension]
    mvo.loc[date] = n['close'].tolist()

  return mvo

# %% [markdown]
# ### Helper functions for mean returns and variance-covariance matrix

# %%
# Codes in this section partially refer to Dr G A Vijayalakshmi Pai

# https://www.kaggle.com/code/vijipai/lesson-5-mean-variance-optimization-of-portfolios/notebook

def StockReturnsComputing(StockPrice, Rows, Columns):
  import numpy as np
  StockReturn = np.zeros([Rows-1, Columns])
  for j in range(Columns):        # j: Assets
    for i in range(Rows-1):     # i: Daily Prices
      StockReturn[i,j]=((StockPrice[i+1, j]-StockPrice[i,j])/StockPrice[i,j])* 100

  return StockReturn

# %% [markdown]
# ### Calculate the weights for mean-variance

# %%
train_mvo = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE).reset_index()
trade_mvo = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE).reset_index()

# %%
StockData = process_df_for_mvo(train_mvo)
TradeData = process_df_for_mvo(trade_mvo)

TradeData.to_numpy()
# Out:
# array([[172.25990295, 252.19830322, 145.90786743, ...,  27.74454689,
#          20.24555588,  52.26918793],
#        [170.92149353, 247.17918396, 141.58374023, ...,  27.93672752,
#          20.36294556,  51.93944168],
#        [172.17070007, 251.37437439, 143.12597656, ...,  27.55236053,
#          20.1281662 ,  52.5630188 ],
#        ...,
#        [246.71646118, 312.86508179, 291.63308716, ...,  42.33452988,
#          11.38000011,  97.18748474],
#        [240.04521179, 303.69613647, 294.37704468, ...,  41.82120895,
#          11.03999996,  95.70514679],
#        [236.98922729, 303.14102173, 292.48812866, ...,  41.90837479,
#          11.22999954,  96.29212189]])

# %%
#compute asset returns
arStockPrices = np.asarray(StockData)
[Rows, Cols]=arStockPrices.shape
arReturns = StockReturnsComputing(arStockPrices, Rows, Cols)

#compute mean returns and variance covariance matrix of returns
meanReturns = np.mean(arReturns, axis = 0)
covReturns = np.cov(arReturns, rowvar=False)

#set precision for printing results
np.set_printoptions(precision=3, suppress = True)

#display mean returns and variance-covariance matrix of returns
print('Mean returns of assets in k-portfolio 1\n', meanReturns)
print('Variance-Covariance matrix of returns\n', covReturns)
# Out:
# Mean returns of assets in k-portfolio 1
#  [0.111 0.065 0.06  0.069 0.072 0.095 0.047 0.052 0.044 0.041 0.089 0.065
#  0.027 0.046 0.043 0.061 0.038 0.06  0.025 0.053 0.089 0.071 0.043 0.054
#  0.099 0.084 0.027 0.012 0.048]
# Variance-Covariance matrix of returns
#  [[3.196 0.949 1.409 1.618 1.351 1.859 1.415 1.091 1.236 1.404 1.247 1.242
#   1.022 1.667 0.667 1.294 0.693 0.835 1.068 0.693 1.739 1.329 0.696 0.837
#   1.124 1.414 0.543 0.983 0.655]
#  [0.949 2.305 1.006 0.93  0.992 1.097 0.964 0.865 0.875 1.039 0.921 0.973
#   0.635 0.682 0.544 0.782 0.581 0.471 0.633 0.607 0.61  0.591 0.579 0.671
#   0.604 0.601 1.289 0.671 0.498]
#  [0.983 0.998 1.251 1.417 1.242 1.072 1.062 1.049 1.083 1.25  0.974 1.145
#   0.967 1.146 0.758 1.272 0.709 0.624 1.09  0.731 0.999 0.983 0.708 0.895
#   0.979 0.945 0.671 3.182 0.74 ]
#  [0.655 0.61  0.582 0.597 0.588 0.637 0.684 0.506 0.595 0.603 0.741 0.577
#   0.53  0.697 0.515 0.617 0.509 0.476 0.55  0.51  0.705 0.625 0.612 0.555
#   0.613 0.558 0.498 0.74  1.469]]

# %% [markdown]
# ### Use PyPortfolioOpt

# %%
from pypfopt.efficient_frontier import EfficientFrontier

ef_mean = EfficientFrontier(meanReturns, covReturns, weight_bounds=(0, 0.5))
raw_weights_mean = ef_mean.max_sharpe()
cleaned_weights_mean = ef_mean.clean_weights()
mvo_weights = np.array([1000000 * cleaned_weights_mean[i] for i in range(29)])
mvo_weights
# Out:
# array([248190.,  14900.,      0.,      0.,      0.,   5590.,      0.,
#             0.,      0.,      0., 190580.,      0.,      0.,      0.,
#             0.,      0.,      0., 111530.,      0.,  24280.,  13000.,
#             0.,      0.,      0., 277910.,  42680.,      0.,      0.,
#         71340.])

# %%
LastPrice = np.array([1/p for p in StockData.tail(1).to_numpy()[0]])
Initial_Portfolio = np.multiply(mvo_weights, LastPrice)
Initial_Portfolio
# Out:
# array([1462.163,   58.542,    0.   ,    0.   ,    0.   ,   27.808,
#           0.   ,    0.   ,    0.   ,    0.   ,  658.71 ,    0.   ,
#           0.   ,    0.   ,    0.   ,    0.   ,    0.   ,  441.225,
#           0.   ,  248.607,   41.724,    0.   ,    0.   ,    0.   ,
#         568.146,  188.001,    0.   ,    0.   , 1366.308])

# %%
Portfolio_Assets = TradeData @ Initial_Portfolio
MVO_result = pd.DataFrame(Portfolio_Assets, columns=["Mean Var"])
# MVO_result

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtesting Results
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
df_result_ppo = df_account_value_ppo.set_index(df_account_value_ppo.columns[0])
df_result_ppo.rename(columns = {'account_value':'ppo'}, inplace = True)
#baseline stats
print("==============Get Baseline Stats===========")
df_dji_ = get_baseline(
        ticker="^DJI",
        start = TRADE_START_DATE,
        end = TRADE_END_DATE)
stats = backtest_stats(df_dji_, value_col_name = 'close')
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value_ppo['date']
df_dji['account_value'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]
df_dji.to_csv("df_dji.csv")
df_dji = df_dji.set_index(df_dji.columns[0])
df_dji.to_csv("df_dji+.csv")

result = pd.DataFrame()
result = pd.merge(result, df_result_ppo, how='outer', left_index=True, right_index=True)
result = pd.merge(result, MVO_result, how='outer', left_index=True, right_index=True)
print(result.head())
result = pd.merge(result, df_dji, how='outer', left_index=True, right_index=True)
# result.columns = ['a2c', 'ddpg', 'td3', 'ppo', 'sac', 'mean var', 'dji']
result.columns = [ 'ppo', 'mean var']
print("result: ", result)
result.to_csv("result.csv")
# Out:
#                     ddpg      Mean Var
# date
# 2023-10-02  1.000000e+06  1.005879e+06
# 2023-10-03  9.966336e+05  9.929164e+05
# 2023-10-04  9.975969e+05  9.981443e+05
# 2023-10-05  9.977129e+05  1.000998e+06
# 2023-10-06  1.006425e+06  1.008246e+06
# result:                      ddpg      mean var
# date
# 2023-10-02  1.000000e+06  1.005879e+06
# 2023-10-03  9.966336e+05  9.929164e+05
# 2023-10-04  9.975969e+05  9.981443e+05
# 2023-10-05  9.977129e+05  1.000998e+06
# 2023-10-06  1.006425e+06  1.008246e+06
# ...                  ...           ...
# 2025-02-21  1.361228e+06  1.263438e+06
# 2025-02-24  1.366863e+06  1.261625e+06
# 2025-02-25  1.373314e+06  1.280903e+06
# 2025-02-26  1.365265e+06  1.259473e+06
# 2025-02-27  1.358185e+06  1.261514e+06
#
# [353 rows x 2 columns]

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();
