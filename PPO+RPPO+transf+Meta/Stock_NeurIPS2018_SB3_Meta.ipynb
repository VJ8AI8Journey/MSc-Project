# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/1-Introduction/Stock_NeurIPS2018_SB3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading
#
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Task Description](#0)
# * [2. Install Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. A List of Python Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download and Preprocess Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5. Build Market Environment in OpenAI Gym-style](#4)
#     * [5.1. Data Split](#4.1)
#     * [5.3. Environment for Training](#4.2)
# * [6. Train DRL Agents](#5)
# * [7. Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Task Discription

# %% [markdown]
# We train a DRL agent for stock trading. This task is modeled as a Markov Decision Process (MDP), and the objective function is maximizing (expected) cumulative return.
#
# We specify the state-action-reward as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes many features and learns by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 consituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.
#
#
# The data for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Install Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install packages

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. A list of Python packages
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
# %matplotlib inline

import sys
sys.path.append(r"D:\FinRL-master\FinRL-master")

from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor
from finrl.meta.data_processors.processor_yahoofinance import YahooFinanceProcessor
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint


import itertools
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas_datareader/compat/__init__.py:11: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   PANDAS_VERSION = LooseVersion(pd.__version__)
# /usr/local/lib/python3.11/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
from finrl import config
from finrl import config_tickers
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance provides stock data, financial news, financial reports, etc. Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** in FinRL-Meta to fetch data via Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()

# %%
# from config.py, TRAIN_START_DATE is a string
TRAIN_START_DATE
# from config.py, TRAIN_END_DATE is a string
TRAIN_END_DATE
# Out:
# '2020-07-31'

# %%
TRAIN_START_DATE = '2010-01-01'
TRAIN_END_DATE = '2023-10-01'
TRADE_START_DATE = '2023-10-01'
TRADE_END_DATE = '2025-06-01'

# %%
df = YahooDownloader(start_date = TRAIN_START_DATE,
                    end_date = TRADE_END_DATE,
                    ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
# yfp = YahooFinanceProcessor()
# df = yfp.download_data(['AXP', 'AMGN', 'AAPL'], '2010-01-01', '2010-02-01', '1m')
print(df)
# Out:
# YF deprecation warning: set proxy via new config function: yf.set_config(proxy=proxy)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (112073, 8)
# Price         date       close        high         low        open     volume  \
# 0       2010-01-04    6.431897    6.446624    6.382909    6.414466  493729600
# 1       2010-01-04   39.913246   40.016969   39.111109   39.159514    5277400
# 2       2010-01-04   32.637955   32.781524   32.215226   32.550221    6894300
# 3       2010-01-04   43.777538   43.941177   42.702190   43.419090    6186700
# 4       2010-01-04   39.403473   39.834185   38.703564   38.797785    7325600
# ...            ...         ...         ...         ...         ...        ...
# 112068  2025-02-28  469.605164  470.989374  459.243337  461.734915    6146300
# 112069  2025-02-28  362.108612  363.396482  353.123534  354.121876   15857300
# 112070  2025-02-28   41.743721   42.382952   41.269142   42.063338   25197500
# 112071  2025-02-28   10.680000   11.490000   10.480000   10.630000   52407400
# 112072  2025-02-28   98.102753   98.351467   96.670158   97.286971   25451300
#
# Price    tic  day
# 0       AAPL    0
# 1       AMGN    0
# 2        AXP    0
# 3         BA    0
# 4        CAT    0
# ...      ...  ...
# 112068   UNH    4
# 112069     V    4
# 112070    VZ    4
# 112071   WBA    4
# 112072   WMT    4
#
# [112073 rows x 8 columns]

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
df.shape
# Out:
# (112073, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
# Price        date      close       high        low       open     volume  \
# 0      2010-01-04   6.431897   6.446624   6.382909   6.414466  493729600
# 1      2010-01-04  39.913246  40.016969  39.111109  39.159514    5277400
# 2      2010-01-04  32.637955  32.781524  32.215226  32.550221    6894300
# 3      2010-01-04  43.777538  43.941177  42.702190  43.419090    6186700
# 4      2010-01-04  39.403473  39.834185  38.703564  38.797785    7325600
#
# Price   tic  day
# 0      AAPL    0
# 1      AMGN    0
# 2       AXP    0
# 3        BA    0
# 4       CAT    0

# %% [markdown]
# # Part 4: Preprocess Data
# We need to check for missing data and do feature engineering to convert the data point into a state.
# * **Adding technical indicators**. In practical trading, various information needs to be taken into account, such as historical prices, current holding shares, technical indicators, etc. Here, we demonstrate two trend-following technical indicators: MACD and RSI.
# * **Adding turbulence index**. Risk-aversion reflects whether an investor prefers to protect the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the turbulence index that measures extreme fluctuation of asset price.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=True,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3812, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
print(processed)
# Out:
#               date       close        high         low        open     volume  \
# 0       2010-01-04    6.431897    6.446624    6.382909    6.414466  493729600
# 1       2010-01-04   39.913246   40.016969   39.111109   39.159514    5277400
# 2       2010-01-04   32.637955   32.781524   32.215226   32.550221    6894300
# 3       2010-01-04   43.777538   43.941177   42.702190   43.419090    6186700
# 4       2010-01-04   39.403473   39.834185   38.703564   38.797785    7325600
# ...            ...         ...         ...         ...         ...        ...
# 110543  2025-02-27  463.277344  470.040224  459.777246  460.914305    4216800
# 110544  2025-02-27  355.150177  359.712607  351.096911  351.316547    7298100
# 110545  2025-02-27   41.908375   42.053652   41.540332   41.724355   19212300
# 110546  2025-02-27   11.230000   11.850000   11.190000   11.700000   18971100
# 110547  2025-02-27   96.292122   97.535692   95.317160   95.406701   16431500
#
#          tic  day       macd     boll_ub     boll_lb      rsi_30      cci_30  \
0.0

# %%
mvo_df = processed_full.sort_values(['date','tic'],ignore_index=True)[['date','tic','close']]

# %% [markdown]
# <a id='4'></a>
# # Part 5. Build A Market Environment in OpenAI Gym-style
# The training process involves observing stock price change, taking an action and reward's calculation. By interacting with the market environment, the agent will eventually derive a trading strategy that may maximize (expected) rewards.
#
# Our market environment, based on OpenAI Gym, simulates stock markets with historical market data.

# %% [markdown]
# ## Data Split
# We split the data into training set and testing set as follows:
#
# Training data period: 2009-01-01 to 2020-07-01
#
# Trading data period: 2020-07-01 to 2021-10-31

# %%
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
train_length = len(train)
trade_length = len(trade)
print(train_length)
print(trade_length)
# Out:
# 100311
# 10237

# %%
train.tail()
# Out:
#             date  tic       close        high         low        open  \
# 3458  2023-09-29  UNH  489.152222  494.672516  488.773839  494.643412
# 3458  2023-09-29    V  227.020615  230.001369  226.665293  229.813836
# 3458  2023-09-29   VZ   28.312365   28.609378   28.277421   28.495813
# 3458  2023-09-29  WBA   20.083014   20.254587   18.854915   18.963277
# 3458  2023-09-29  WMT   52.213684   53.258414   51.972087   53.225766
#
#           volume  day      macd     boll_ub     boll_lb     rsi_30  \
# 3458   3006200.0  4.0  4.758832  499.945950  450.959732  55.148634
# 3458   6045200.0  4.0 -3.066167  251.200594  224.032589  41.887466
# 3458  19787600.0  4.0 -0.276669   30.421854   28.184128  41.243804
# 3458  25663400.0  4.0 -1.050146   20.962601   18.592988  36.119169
# 3458  18842400.0  4.0  0.139828   54.153628   52.232614  50.578492
#
#           cci_30      dx_30  close_30_sma  close_60_sma    vix  turbulence
# 3458  128.373463  19.202214    475.052338    477.039837  17.52   57.508317
# 3458 -154.262894  36.909070    238.148424    237.149244  17.52   57.508317
# 3458 -137.570645  33.867316     29.353076     29.363413  17.52   57.508317
# 3458  -53.011613  26.754668     20.958936     23.656806  17.52   57.508317
# 3458  -24.941299  17.468385     52.741928     52.075984  17.52   57.508317

# %%
trade.head()
# Out:
#          date   tic       close        high         low        open  \
# 0  2023-10-02  AAPL  172.259903  172.805189  169.464080  169.751602
# 0  2023-10-02  AMGN  252.198318  254.262794  250.370595  253.524127
# 0  2023-10-02   AXP  145.907852  146.317814  144.531558  144.873186
# 0  2023-10-02    BA  187.830002  192.440002  186.929993  191.470001
# 0  2023-10-02   CAT  262.851074  267.774933  261.419371  263.741058
#
#        volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  52164500.0  0.0 -2.561662  183.575469  165.836037  45.243155  -87.977329
# 0   1912300.0  0.0  3.867168  261.151714  237.536320  59.425484   72.229010
# 0   2657600.0  0.0 -3.052553  160.817392  143.761848  37.445502 -174.733595
# 0   5244700.0  0.0 -8.257769  223.250012  185.200986  32.814602 -138.625438
# 0   1778200.0  0.0 -0.878848  277.101089  259.928766  51.346824  -69.196499
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  26.128931    176.566326    181.009779  17.610001   34.480829
# 0  31.542893    247.539646    237.412817  17.610001   34.480829
# 0  36.526638    153.348369    158.819425  17.610001   34.480829
# 0  66.417390    211.389666    218.712000  17.610001   34.480829
# 0   1.038574    268.083487    264.021851  17.610001   34.480829

# %%
INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for Training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**. Users are also encouraged to try **ElegantRL** and **Ray RLlib**.
# * FinRL includes fine-tuned standard DRL algorithms, such as DQN, DDPG, Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
agent = DRLAgent(env = env_train)
if_using_ppo = True

# %%
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np

class MetaPPOCallback(BaseCallback):
    def __init__(self, check_freq=1000, verbose=1):
        super(MetaPPOCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.rewards = []
        self.last_eval_step = 0

    def _on_step(self):
        reward = self.locals.get("rewards", [None])[0]
        if reward is not None:
            self.rewards.append(reward)
        return True

    def _on_rollout_end(self):
        if (self.num_timesteps - self.last_eval_step) >= self.check_freq:
            model = self.model
            recent_rewards = self.rewards[-100:]
            if not recent_rewards:
                return True

            mean_reward = np.mean(recent_rewards)
            std_reward = np.std(recent_rewards)

            # 🧠 Rule 1: Adapt learning rate
            try:
                current_lr = float(model.learning_rate)
                new_lr = max(current_lr * 0.9, 1e-6)
                model.learning_rate = new_lr
                if self.verbose:
                    print(f"[MetaPPO] Lowering learning rate: {new_lr:.6f}")
            except Exception as e:
                if self.verbose:
                    print(f"[MetaPPO] Failed to adjust learning rate: {e}")

            # 🧠 Rule 2: Adapt entropy coefficient (manual override property)
            try:
                current_ent_coef = float(getattr(model, "entropy_coef_value", 0.01))
                new_ent_coef = min(current_ent_coef * 1.1, 0.1)
                model.entropy_coef_value = new_ent_coef  # Track manually
                model.ent_coef = new_ent_coef             # Override used in loss
                if self.verbose:
                    print(f"[MetaPPO] Increasing entropy coef: {new_ent_coef:.6f}")
            except Exception as e:
                if self.verbose:
                    print(f"[MetaPPO] Failed to adjust entropy coef: {e}")

            # 🧠 Rule 3: Adapt clip range (must remain callable)
            try:
                current_clip = float(model.clip_range(1.0))  # Evaluate schedule
                new_clip = max(current_clip * 0.95, 0.05)
                model.clip_range = lambda _: new_clip  # Callable override
                if self.verbose:
                    print(f"[MetaPPO] Decreasing clip range: {new_clip:.4f}")
            except Exception as e:
                if self.verbose:
                    print(f"[MetaPPO] Failed to adjust clip range: {e}")

            self.last_eval_step = self.num_timesteps

        return True

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)
model_ppo.entropy_coef_value = model_ppo.ent_coef

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to results/ppo

# %%
# ✅ Manually run training with callback
meta_callback = MetaPPOCallback(check_freq=1000, verbose=1)

model_ppo.learn(
    total_timesteps=200000,
    callback=meta_callback,
    tb_log_name='ppo'  # Only works if model supports tensorboard log name directly
)

trained_ppo = model_ppo  # Final model after learning
# Out:
# [MetaPPO] Lowering learning rate: 0.000225
# [MetaPPO] Increasing entropy coef: 0.011000
# [MetaPPO] Decreasing clip range: 0.1900
# -----------------------------
# | time/              |      |
# |    fps             | 74   |
# |    iterations      | 1    |
# |    time_elapsed    | 27   |
# |    total_timesteps | 2048 |
# -----------------------------
# [MetaPPO] Lowering learning rate: 0.000203
# [MetaPPO] Increasing entropy coef: 0.012100
# [MetaPPO] Decreasing clip range: 0.1805
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 2           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017511623 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.19        |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0214     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4           |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0252     |
# |    std                  | 1           |
# |    value_loss           | 11.3        |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000182
# [MetaPPO] Increasing entropy coef: 0.013310
# [MetaPPO] Decreasing clip range: 0.1715
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 73         |
# |    iterations           | 3          |
# |    time_elapsed         | 84         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01683275 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.18       |
# |    entropy_loss         | -41.3      |
# |    explained_variance   | 0.00915    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 31.6       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0151    |
# |    std                  | 1          |
# |    value_loss           | 54.2       |
# ----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000164
# [MetaPPO] Increasing entropy coef: 0.014641
# [MetaPPO] Decreasing clip range: 0.1629
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 72         |
# |    iterations           | 4          |
# |    time_elapsed         | 113        |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01265749 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.171      |
# |    entropy_loss         | -41.3      |
# |    explained_variance   | -0.0111    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 13.1       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0195    |
# |    std                  | 1.01       |
# |    value_loss           | 33.8       |
# ----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000148
# [MetaPPO] Increasing entropy coef: 0.016105
# [MetaPPO] Decreasing clip range: 0.1548
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 5           |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019300342 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.163       |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | 0.00674     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.47        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 1.01        |
# |    value_loss           | 30.1        |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000133
# [MetaPPO] Increasing entropy coef: 0.017716
# [MetaPPO] Decreasing clip range: 0.1470
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 6           |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014676498 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.155       |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | 0.00749     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 41.4        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 1.01        |
# |    value_loss           | 101         |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000120
# [MetaPPO] Increasing entropy coef: 0.019487
# [MetaPPO] Decreasing clip range: 0.1397
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 7           |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.017508637 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.147       |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | 0.0347      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.08        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 1.02        |
# |    value_loss           | 15          |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000108
# [MetaPPO] Increasing entropy coef: 0.021436
# [MetaPPO] Decreasing clip range: 0.1327
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 8           |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014439838 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.14        |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | 0.00884     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 66.4        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 1.02        |
# |    value_loss           | 105         |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000097
# [MetaPPO] Increasing entropy coef: 0.023579
# [MetaPPO] Decreasing clip range: 0.1260
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 9           |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.018849831 |
# |    clip_fraction        | 0.41        |
# |    clip_range           | 0.133       |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.00365     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.78        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 1.03        |
# |    value_loss           | 19.4        |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000087
# [MetaPPO] Increasing entropy coef: 0.025937
# [MetaPPO] Decreasing clip range: 0.1197
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 10          |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.019787148 |
# |    clip_fraction        | 0.394       |
# |    clip_range           | 0.126       |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.00834     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 25.8        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00743    |
# |    std                  | 1.03        |
# |    value_loss           | 63.7        |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000078
# [MetaPPO] Increasing entropy coef: 0.028531
# [MetaPPO] Decreasing clip range: 0.1138
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 11          |
# |    time_elapsed         | 312         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010845477 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.12        |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | -0.00834    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 42.2        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00803    |
# |    std                  | 1.03        |
# |    value_loss           | 65.1        |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000071
# [MetaPPO] Increasing entropy coef: 0.031384
# [MetaPPO] Decreasing clip range: 0.1081
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 12          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.015455123 |
# |    clip_fraction        | 0.349       |
# |    clip_range           | 0.114       |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | 0.0322      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.6        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00686    |
# |    std                  | 1.04        |
# |    value_loss           | 24.7        |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000064
# [MetaPPO] Increasing entropy coef: 0.034523
# [MetaPPO] Decreasing clip range: 0.1027
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 13          |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.013203777 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.108       |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | 0.00948     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 61.5        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00377    |
# |    std                  | 1.05        |
# |    value_loss           | 122         |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000057
# [MetaPPO] Increasing entropy coef: 0.037975
# [MetaPPO] Decreasing clip range: 0.0975
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 14          |
# |    time_elapsed         | 399         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015257257 |
# |    clip_fraction        | 0.472       |
# |    clip_range           | 0.103       |
# |    entropy_loss         | -42.6       |
# |    explained_variance   | 0.026       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.89        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00644    |
# |    std                  | 1.05        |
# |    value_loss           | 21.1        |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000051
# [MetaPPO] Increasing entropy coef: 0.041772
# [MetaPPO] Decreasing clip range: 0.0927
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 15          |
# |    time_elapsed         | 428         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010359898 |
# |    clip_fraction        | 0.335       |
# |    clip_range           | 0.0975      |
# |    entropy_loss         | -42.7       |
# |    explained_variance   | 0.0407      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21.2        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00487    |
# |    std                  | 1.06        |
# |    value_loss           | 52.6        |
# -----------------------------------------
# day: 3458, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 4040105.13
# total_reward: 3040105.13
# total_cost: 463922.36
# total_trades: 93477
# Sharpe: 0.671
# =================================
# [MetaPPO] Lowering learning rate: 0.000046
# [MetaPPO] Increasing entropy coef: 0.045950
# [MetaPPO] Decreasing clip range: 0.0880
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 16          |
# |    time_elapsed         | 457         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011180193 |
# |    clip_fraction        | 0.361       |
# |    clip_range           | 0.0927      |
# |    entropy_loss         | -42.9       |
# |    explained_variance   | -0.00997    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 35.1        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00255    |
# |    std                  | 1.07        |
# |    value_loss           | 71.8        |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000042
# [MetaPPO] Increasing entropy coef: 0.050545
# [MetaPPO] Decreasing clip range: 0.0836
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 17          |
# |    time_elapsed         | 485         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.013715966 |
# |    clip_fraction        | 0.409       |
# |    clip_range           | 0.088       |
# |    entropy_loss         | -43.1       |
# |    explained_variance   | 0.0112      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 24.3        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000879   |
# |    std                  | 1.07        |
# |    value_loss           | 45.5        |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000038
# [MetaPPO] Increasing entropy coef: 0.055599
# [MetaPPO] Decreasing clip range: 0.0794
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 71         |
# |    iterations           | 18         |
# |    time_elapsed         | 514        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.01156611 |
# |    clip_fraction        | 0.405      |
# |    clip_range           | 0.0836     |
# |    entropy_loss         | -43.3      |
# |    explained_variance   | 0.016      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 34.1       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | 0.00119    |
# |    std                  | 1.08       |
# |    value_loss           | 73.4       |
# ----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000034
# [MetaPPO] Increasing entropy coef: 0.061159
# [MetaPPO] Decreasing clip range: 0.0755
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 19          |
# |    time_elapsed         | 543         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012666689 |
# |    clip_fraction        | 0.441       |
# |    clip_range           | 0.0794      |
# |    entropy_loss         | -43.5       |
# |    explained_variance   | -0.0026     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.78        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00117    |
# |    std                  | 1.09        |
# |    value_loss           | 19.7        |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000030
# [MetaPPO] Increasing entropy coef: 0.067275
# [MetaPPO] Decreasing clip range: 0.0717
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 20          |
# |    time_elapsed         | 571         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008529975 |
# |    clip_fraction        | 0.381       |
# |    clip_range           | 0.0755      |
# |    entropy_loss         | -43.7       |
# |    explained_variance   | 0.0297      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 46.7        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00105    |
# |    std                  | 1.1         |
# |    value_loss           | 68.3        |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000027
# [MetaPPO] Increasing entropy coef: 0.074002
# [MetaPPO] Decreasing clip range: 0.0681
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 21          |
# |    time_elapsed         | 599         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010910375 |
# |    clip_fraction        | 0.425       |
# |    clip_range           | 0.0717      |
# |    entropy_loss         | -43.9       |
# |    explained_variance   | 0.00949     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21.6        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00033     |
# |    std                  | 1.1         |
# |    value_loss           | 46          |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000025
# [MetaPPO] Increasing entropy coef: 0.081403
# [MetaPPO] Decreasing clip range: 0.0647
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 22          |
# |    time_elapsed         | 628         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012074988 |
# |    clip_fraction        | 0.521       |
# |    clip_range           | 0.0681      |
# |    entropy_loss         | -44.2       |
# |    explained_variance   | -0.0111     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 23.4        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00309     |
# |    std                  | 1.12        |
# |    value_loss           | 36.1        |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000022
# [MetaPPO] Increasing entropy coef: 0.089543
# [MetaPPO] Decreasing clip range: 0.0615
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 23          |
# |    time_elapsed         | 657         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.015493651 |
# |    clip_fraction        | 0.608       |
# |    clip_range           | 0.0647      |
# |    entropy_loss         | -44.5       |
# |    explained_variance   | 0.0335      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 27.5        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.0111      |
# |    std                  | 1.13        |
# |    value_loss           | 54.6        |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000020
# [MetaPPO] Increasing entropy coef: 0.098497
# [MetaPPO] Decreasing clip range: 0.0584
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 24          |
# |    time_elapsed         | 685         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012657808 |
# |    clip_fraction        | 0.596       |
# |    clip_range           | 0.0615      |
# |    entropy_loss         | -44.9       |
# |    explained_variance   | 0.0676      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.48        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00629     |
# |    std                  | 1.15        |
# |    value_loss           | 12.6        |
# -----------------------------------------
# [MetaPPO] Lowering learning rate: 0.000018
# [MetaPPO] Increasing entropy coef: 0.100000
# [MetaPPO] Decreasing clip range: 0.0555
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 25          |
# |    time_elapsed         | 713         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008629626 |
# |    clip_fraction        | 0.397       |
# |    clip_range           | 0.0584      |
# |    entropy_loss         | -45.2       |
# |    explained_variance   | 0.0457      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 32.9        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00439     |
# |    std                  | 1.16        |
# |    value_loss           | 61.6        |
# -----------------------------------------

# %% [markdown]
# ## In-sample Performance
#
# Assume that the initial capital is $1,000,000.

# %% [markdown]
# ### Set turbulence threshold
# Set the turbulence threshold to be greater than the maximum of insample turbulence data. If current turbulence index is greater than the threshold, then we assume that the current market is volatile

# %%
data_risk_indicator = processed_full[(processed_full.date<TRAIN_END_DATE) & (processed_full.date>=TRAIN_START_DATE)]
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])

# %%
insample_risk_indicator.vix.describe()
# Out:
# count    3459.000000
# mean       18.633854
# std         7.150486
# min         9.140000
# 25%        13.705000
# 50%        16.870001
# 75%        21.570000
# max        82.690002
# Name: vix, dtype: float64

# %%
insample_risk_indicator.vix.quantile(0.996)
# Out:
# np.float64(54.89679946899445)

# %%
insample_risk_indicator.turbulence.describe()
# Out:
# count    3459.000000
# mean       34.754942
# std        42.349260
# min         0.000000
# 25%        15.118497
# 50%        24.215430
# 75%        39.727019
# max       652.503087
# Name: turbulence, dtype: float64

# %%
insample_risk_indicator.turbulence.quantile(0.996)
# Out:
# np.float64(263.5026845904692)

# %% [markdown]
# ### Trading (Out-of-sample Performance)
#
# We update periodically in order to take full advantage of the data, e.g., retrain quarterly, monthly or weekly. We also tune the parameters along the way, in this notebook we use the in-sample data from 2009-01 to 2020-07 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 55,risk_indicator_col='vix', **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
trade.head()
# Out:
#          date   tic       close        high         low        open  \
# 0  2023-10-02  AAPL  172.259903  172.805189  169.464080  169.751602
# 0  2023-10-02  AMGN  252.198318  254.262794  250.370595  253.524127
# 0  2023-10-02   AXP  145.907852  146.317814  144.531558  144.873186
# 0  2023-10-02    BA  187.830002  192.440002  186.929993  191.470001
# 0  2023-10-02   CAT  262.851074  267.774933  261.419371  263.741058
#
#        volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  52164500.0  0.0 -2.561662  183.575469  165.836037  45.243155  -87.977329
# 0   1912300.0  0.0  3.867168  261.151714  237.536320  59.425484   72.229010
# 0   2657600.0  0.0 -3.052553  160.817392  143.761848  37.445502 -174.733595
# 0   5244700.0  0.0 -8.257769  223.250012  185.200986  32.814602 -138.625438
# 0   1778200.0  0.0 -0.878848  277.101089  259.928766  51.346824  -69.196499
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  26.128931    176.566326    181.009779  17.610001   34.480829
# 0  31.542893    247.539646    237.412817  17.610001   34.480829
# 0  36.526638    153.348369    158.819425  17.610001   34.480829
# 0  66.417390    211.389666    218.712000  17.610001   34.480829
# 0   1.038574    268.083487    264.021851  17.610001   34.480829

# %%
trained_model = trained_ppo  # Make sure this matches your model variable

# ✅ Run prediction using DRLAgent's method
df_account_value_ppo, df_actions_ppo = DRLAgent.DRL_prediction(
    model=trained_model,
    environment=e_trade_gym
)
# Out:
# hit end!

# %% [markdown]
# <a id='7'></a>
# # Part 6.5: Mean Variance Optimization

# %% [markdown]
# Mean Variance optimization is a very classic strategy in portfolio management. Here, we go through the whole process to do the mean variance optimization and add it as a baseline to compare.
#
# First, process dataframe to the form for MVO weight calculation.

# %%
def process_df_for_mvo(df):
  df = df.sort_values(['date','tic'],ignore_index=True)[['date','tic','close']]
  fst = df
  fst = fst.iloc[0:stock_dimension, :]
  tic = fst['tic'].tolist()

  mvo = pd.DataFrame()

  for k in range(len(tic)):
    mvo[tic[k]] = 0

  for i in range(df.shape[0]//stock_dimension):
    n = df
    n = n.iloc[i * stock_dimension:(i+1) * stock_dimension, :]
    date = n['date'][i*stock_dimension]
    mvo.loc[date] = n['close'].tolist()

  return mvo

# %% [markdown]
# ### Helper functions for mean returns and variance-covariance matrix

# %%
# Codes in this section partially refer to Dr G A Vijayalakshmi Pai

# https://www.kaggle.com/code/vijipai/lesson-5-mean-variance-optimization-of-portfolios/notebook

def StockReturnsComputing(StockPrice, Rows, Columns):
  import numpy as np
  StockReturn = np.zeros([Rows-1, Columns])
  for j in range(Columns):        # j: Assets
    for i in range(Rows-1):     # i: Daily Prices
      StockReturn[i,j]=((StockPrice[i+1, j]-StockPrice[i,j])/StockPrice[i,j])* 100

  return StockReturn

# %% [markdown]
# ### Calculate the weights for mean-variance

# %%
train_mvo = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE).reset_index()
trade_mvo = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE).reset_index()

# %%
StockData = process_df_for_mvo(train_mvo)
TradeData = process_df_for_mvo(trade_mvo)

TradeData.to_numpy()
# Out:
# array([[172.26 , 252.198, 145.908, ...,  27.745,  20.246,  52.269],
#        [170.921, 247.179, 141.584, ...,  27.937,  20.363,  51.939],
#        [172.171, 251.374, 143.126, ...,  27.552,  20.128,  52.563],
#        ...,
#        [246.716, 312.865, 291.633, ...,  42.335,  11.38 ,  97.187],
#        [240.045, 303.696, 294.377, ...,  41.821,  11.04 ,  95.705],
#        [236.989, 303.141, 292.488, ...,  41.908,  11.23 ,  96.292]])

# %%
#compute asset returns
arStockPrices = np.asarray(StockData)
[Rows, Cols]=arStockPrices.shape
arReturns = StockReturnsComputing(arStockPrices, Rows, Cols)

#compute mean returns and variance covariance matrix of returns
meanReturns = np.mean(arReturns, axis = 0)
covReturns = np.cov(arReturns, rowvar=False)

#set precision for printing results
np.set_printoptions(precision=3, suppress = True)

#display mean returns and variance-covariance matrix of returns
print('Mean returns of assets in k-portfolio 1\n', meanReturns)
print('Variance-Covariance matrix of returns\n', covReturns)
# Out:
# Mean returns of assets in k-portfolio 1
#  [0.111 0.065 0.06  0.069 0.072 0.095 0.047 0.052 0.044 0.041 0.089 0.065
#  0.027 0.046 0.043 0.061 0.038 0.06  0.025 0.053 0.089 0.071 0.043 0.054
#  0.099 0.084 0.027 0.012 0.048]
# Variance-Covariance matrix of returns
#  [[3.196 0.949 1.409 1.618 1.351 1.859 1.415 1.091 1.236 1.404 1.247 1.242
#   1.022 1.667 0.667 1.294 0.693 0.835 1.068 0.693 1.739 1.329 0.696 0.837
#   1.124 1.414 0.543 0.983 0.655]
#  [0.949 2.305 1.006 0.93  0.992 1.097 0.964 0.865 0.875 1.039 0.921 0.973
#   0.808 1.104 0.865 1.052 0.625 0.641 0.883 1.002 1.004 0.828 0.699 0.811
#   1.076 0.98  0.609 0.998 0.61 ]
#  [1.409 1.006 3.426 2.516 1.926 1.679 1.435 1.805 1.806 2.225 1.403 1.801
#   1.314 1.58  0.805 2.337 0.971 1.053 1.399 0.877 1.435 1.546 0.723 1.464
#   1.341 1.858 0.736 1.251 0.582]
#  [1.618 0.93  2.516 5.157 2.126 1.819 1.487 2.018 1.951 2.194 1.527 2.079
#   1.456 1.822 0.817 2.24  1.062 1.172 1.464 0.843 1.501 1.72  0.727 1.527
#   1.376 1.734 0.721 1.417 0.597]
]

# %% [markdown]
# ### Use PyPortfolioOpt

# %%
from pypfopt.efficient_frontier import EfficientFrontier

ef_mean = EfficientFrontier(meanReturns, covReturns, weight_bounds=(0, 0.5))
raw_weights_mean = ef_mean.max_sharpe()
cleaned_weights_mean = ef_mean.clean_weights()
mvo_weights = np.array([1000000 * cleaned_weights_mean[i] for i in range(29)])
mvo_weights
# Out:
# array([248190.,  14900.,      0.,      0.,      0.,   5590.,      0.,
#             0.,      0.,      0., 190580.,      0.,      0.,      0.,
#             0.,      0.,      0., 111530.,      0.,  24280.,  13000.,
#             0.,      0.,      0., 277910.,  42680.,      0.,      0.,
#         71340.])

# %%
LastPrice = np.array([1/p for p in StockData.tail(1).to_numpy()[0]])
Initial_Portfolio = np.multiply(mvo_weights, LastPrice)
Initial_Portfolio
# Out:
# array([1462.163,   58.542,    0.   ,    0.   ,    0.   ,   27.808,
#           0.   ,    0.   ,    0.   ,    0.   ,  658.71 ,    0.   ,
#           0.   ,    0.   ,    0.   ,    0.   ,    0.   ,  441.225,
#           0.   ,  248.607,   41.724,    0.   ,    0.   ,    0.   ,
#         568.146,  188.001,    0.   ,    0.   , 1366.308])

# %%
Portfolio_Assets = TradeData @ Initial_Portfolio
MVO_result = pd.DataFrame(Portfolio_Assets, columns=["Mean Var"])
# MVO_result

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtesting Results
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
# ✅ PPO (Meta-PPO) Result
df_result_ppo = df_account_value_ppo.set_index(df_account_value_ppo.columns[0])
df_result_ppo.rename(columns={'account_value': 'ppo_meta'}, inplace=True)

# ✅ MVO Result (ensure it's a DataFrame)
if isinstance(MVO_result, pd.Series):
    MVO_result = MVO_result.to_frame(name='mean var')
elif isinstance(MVO_result, pd.DataFrame):
    MVO_result.columns = ['mean var']

# ✅ Merge Meta-PPO with MVO
result = pd.merge(df_result_ppo, MVO_result, how='outer', left_index=True, right_index=True)

# ✅ Final columns and output
result.columns = ['ppo_meta', 'mean var']
print(result.head())
print("Final result comparison:\n", result)

# ✅ Save to CSV
result.to_csv("result_meta_ppo_vs_mvo.csv")
# Out:
#                 ppo_meta      mean var
# date
# 2023-10-02  1.000000e+06  1.005879e+06
# 2023-10-03  9.995793e+05  9.929165e+05
# 2023-10-04  9.997410e+05  9.981442e+05
# 2023-10-05  9.996548e+05  1.000998e+06
# 2023-10-06  1.000450e+06  1.008246e+06
# Final result comparison:
#                  ppo_meta      mean var
# date
# 2023-10-02  1.000000e+06  1.005879e+06
# 2023-10-03  9.995793e+05  9.929165e+05
# 2023-10-04  9.997410e+05  9.981442e+05
# 2023-10-05  9.996548e+05  1.000998e+06
# 2023-10-06  1.000450e+06  1.008246e+06
# ...                  ...           ...
# 2025-02-21  1.428441e+06  1.263438e+06
# 2025-02-24  1.439906e+06  1.261625e+06
# 2025-02-25  1.455379e+06  1.280903e+06
# 2025-02-26  1.446275e+06  1.259473e+06
# 2025-02-27  1.454414e+06  1.261514e+06
#
# [353 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# Ensure inline plotting for notebooks
# %matplotlib inline

# Set figure size
plt.rcParams["figure.figsize"] = (15, 5)

# Plot the result DataFrame (Meta-PPO and MVO)
plt.figure()
result.plot(title='Meta-PPO vs MVO: Account Value Over Time')
plt.xlabel("Date")
plt.ylabel("Account Value")
plt.grid(True)
plt.legend(title="Strategy")
plt.tight_layout()
plt.show()

# %%
print("✅ Final Account Values:")
print(result.iloc[-1])
# Out:
# ✅ Final Account Values:
# ppo_meta    1.454414e+06
# mean var    1.261514e+06
# Name: 2025-02-27, dtype: float64
