# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/1-Introduction/Stock_NeurIPS2018_SB3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading
#
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Task Description](#0)
# * [2. Install Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. A List of Python Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download and Preprocess Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5. Build Market Environment in OpenAI Gym-style](#4)
#     * [5.1. Data Split](#4.1)
#     * [5.3. Environment for Training](#4.2)
# * [6. Train DRL Agents](#5)
# * [7. Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Task Discription

# %% [markdown]
# We train a DRL agent for stock trading. This task is modeled as a Markov Decision Process (MDP), and the objective function is maximizing (expected) cumulative return.
#
# We specify the state-action-reward as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes many features and learns by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 consituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.
#
#
# The data for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Install Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install packages

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. A list of Python packages
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
# %matplotlib inline

import sys
sys.path.append(r"D:\FinRL-master\FinRL-master")

from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor
from finrl.meta.data_processors.processor_yahoofinance import YahooFinanceProcessor
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint


import itertools
# Out:
# c:\Users\jvija\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyfolio\pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %%
import torch
import torch.nn as nn
from torch.nn import TransformerEncoder, TransformerEncoderLayer
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
class TransformerFeatureExtractor(BaseFeaturesExtractor):
    def __init__(self, observation_space, d_model=64, nhead=4, num_layers=2):
        super().__init__(observation_space, features_dim=d_model)
        self.seq_len = observation_space.shape[0]
        self.d_model = d_model

        self.linear_embed = nn.Linear(1, d_model)
        self.positional_encoding = nn.Parameter(torch.randn(1, self.seq_len, d_model) * 0.01)  # small init

        encoder_layer = TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=256,
            dropout=0.1,
            batch_first=True,
            activation="relu",
            norm_first=True
        )
        self.transformer = TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.layer_norm = nn.LayerNorm(d_model)

    def forward(self, obs):
        # Step 1: Clean raw observation
        obs = torch.nan_to_num(obs, nan=0.0, posinf=1e6, neginf=-1e6)

        # Step 2: Normalize per sequence (per batch)
        obs = (obs - obs.mean(dim=1, keepdim=True)) / (obs.std(dim=1, keepdim=True) + 1e-8)

        # Step 3: Transformer pipeline
        x = obs.unsqueeze(-1)                               # [B, S] -> [B, S, 1]
        x = self.linear_embed(x)                            # [B, S, D]
        x = x + self.positional_encoding[:, :x.size(1), :]  # Add PE
        x = self.transformer(x)                             # [B, S, D]
        x = self.layer_norm(x)                              # Normalize
        x = x.mean(dim=1)                                   # Pooling [B, D]
        return x

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
from finrl import config
from finrl import config_tickers
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance provides stock data, financial news, financial reports, etc. Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** in FinRL-Meta to fetch data via Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()

# %%
# from config.py, TRAIN_START_DATE is a string
TRAIN_START_DATE
# from config.py, TRAIN_END_DATE is a string
TRAIN_END_DATE
# Out:
# '2020-07-31'

# %%
TRAIN_START_DATE = '2010-01-01'
TRAIN_END_DATE = '2023-10-01'
TRADE_START_DATE = '2023-10-01'
TRADE_END_DATE = '2025-06-01'

# %%
df = YahooDownloader(start_date = TRAIN_START_DATE,
                    end_date = TRADE_END_DATE,
                    ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
# yfp = YahooFinanceProcessor()
# df = yfp.scrap_data(['AXP', 'AMGN', 'AAPL'], '2010-01-01', '2010-02-01')
print(df)
# Out:
# YF deprecation warning: set proxy via new config function: yf.set_config(proxy=proxy)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (94301, 8)
# Price        date       close        high         low        open     volume  \
# 0      2009-01-02    2.727417    2.736134    2.559415    2.581054  746015200
# 1      2009-01-02   40.791451   40.853685   39.933992   40.514850    6547900
# 2      2009-01-02   14.891693   15.038068   14.175228   14.306194   10955700
# 3      2009-01-02   33.941090   34.173615   32.088393   32.103395    7010200
# 4      2009-01-02   30.233936   30.279052   28.816015   28.944917    7117200
# ...           ...         ...         ...         ...         ...        ...
# 94296  2021-10-28  429.862579  432.184418  427.106553  427.559607    1672600
# 94297  2021-10-28  204.013351  213.881524  203.206396  213.162067   23199400
# 94298  2021-10-28   41.607990   41.883803   41.466145   41.568589   18374700
# 94299  2021-10-28   38.449150   38.653233   38.089966   38.432826    4843900
# 94300  2021-10-28   46.984173   47.151917   46.749965   46.949358   12598500
#
# Price   tic  day
# 0      AAPL    4
# 1      AMGN    4
# 2       AXP    4
# 3        BA    4
# 4       CAT    4
# ...     ...  ...
# 94296   UNH    3
# 94297     V    3
# 94298    VZ    3
# 94299   WBA    3
# 94300   WMT    3
#
# [94301 rows x 8 columns]

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
df.shape
# Out:
# (94301, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
# Price        date      close       high        low       open     volume  \
# 0      2009-01-02   2.727417   2.736134   2.559415   2.581054  746015200
# 1      2009-01-02  40.791451  40.853685  39.933992  40.514850    6547900
# 2      2009-01-02  14.891693  15.038068  14.175228  14.306194   10955700
# 3      2009-01-02  33.941090  34.173615  32.088393  32.103395    7010200
# 4      2009-01-02  30.233936  30.279052  28.816015  28.944917    7117200
#
# Price   tic  day
# 0      AAPL    4
# 1      AMGN    4
# 2       AXP    4
# 3        BA    4
# 4       CAT    4

# %% [markdown]
# # Part 4: Preprocess Data
# We need to check for missing data and do feature engineering to convert the data point into a state.
# * **Adding technical indicators**. In practical trading, various information needs to be taken into account, such as historical prices, current holding shares, technical indicators, etc. Here, we demonstrate two trend-following technical indicators: MACD and RSI.
# * **Adding turbulence index**. Risk-aversion reflects whether an investor prefers to protect the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the turbulence index that measures extreme fluctuation of asset price.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=True,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3228, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.sort_values(['date','tic'],ignore_index=True).head(10)
# Out:
#          date   tic      close       high        low       open       volume  \
# 0  2009-01-02  AAPL   2.727417   2.736134   2.559415   2.581054  746015200.0
# 1  2009-01-02  AMGN  40.791451  40.853685  39.933992  40.514850    6547900.0
# 2  2009-01-02   AXP  14.891693  15.038068  14.175228  14.306194   10955700.0
# 3  2009-01-02    BA  33.941090  34.173615  32.088393  32.103395    7010200.0
# 4  2009-01-02   CAT  30.233936  30.279052  28.816015  28.944917    7117200.0
# 5  2009-01-02   CRM   8.431123   8.475732   7.843769   7.955292    4069200.0
# 6  2009-01-02  CSCO  11.099333  11.125511  10.634680  10.739390   40980600.0
# 7  2009-01-02   CVX  39.716721  40.121573  38.190754  38.528129   13695900.0
# 8  2009-01-02   DIS  20.259750  20.352919  19.057039  19.277254    9796600.0
# 9  2009-01-02    GS  65.354599  66.002421  61.912108  63.290607   14088500.0
#
#    day  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  4.0   0.0  2.947758  2.622184   100.0  66.666667  100.0      2.727417
# 1  4.0   0.0  2.947758  2.622184   100.0  66.666667  100.0     40.791451
# 2  4.0   0.0  2.947758  2.622184   100.0  66.666667  100.0     14.891693
# 3  4.0   0.0  2.947758  2.622184   100.0  66.666667  100.0     33.941090
# 4  4.0   0.0  2.947758  2.622184   100.0  66.666667  100.0     30.233936
# 5  4.0   0.0  2.947758  2.622184   100.0  66.666667  100.0      8.431123
# 6  4.0   0.0  2.947758  2.622184   100.0  66.666667  100.0     11.099333
# 7  4.0   0.0  2.947758  2.622184   100.0  66.666667  100.0     39.716721
# 8  4.0   0.0  2.947758  2.622184   100.0  66.666667  100.0     20.259750
# 9  4.0   0.0  2.947758  2.622184   100.0  66.666667  100.0     65.354599
#
#    close_60_sma        vix  turbulence
# 0      2.727417  39.189999         0.0
# 1     40.791451  39.189999         0.0
# 2     14.891693  39.189999         0.0
# 3     33.941090  39.189999         0.0
# 4     30.233936  39.189999         0.0
# 5      8.431123  39.189999         0.0
# 6     11.099333  39.189999         0.0
# 7     39.716721  39.189999         0.0
# 8     20.259750  39.189999         0.0
# 9     65.354599  39.189999         0.0

# %%
mvo_df = processed_full.sort_values(['date','tic'],ignore_index=True)[['date','tic','close']]

# %% [markdown]
# <a id='4'></a>
# # Part 5. Build A Market Environment in OpenAI Gym-style
# The training process involves observing stock price change, taking an action and reward's calculation. By interacting with the market environment, the agent will eventually derive a trading strategy that may maximize (expected) rewards.
#
# Our market environment, based on OpenAI Gym, simulates stock markets with historical market data.

# %% [markdown]
# ## Data Split
# We split the data into training set and testing set as follows:
#
# Training data period: 2009-01-01 to 2020-07-01
#
# Trading data period: 2020-07-01 to 2021-10-31

# %%
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
train_length = len(train)
trade_length = len(trade)
print(train_length)
print(trade_length)
# Out:
# 83897
# 9715

# %%
train.tail()
# Out:
#             date  tic       close        high         low        open  \
# 2892  2020-06-30  UNH  273.307526  274.697460  266.552435  267.395665
# 2892  2020-06-30    V  186.425064  186.984814  183.520170  184.803732
# 2892  2020-06-30   VZ   40.665901   40.783923   40.097921   40.510995
# 2892  2020-06-30  WBA   32.880199   33.027577   32.391533   32.670771
# 2892  2020-06-30  WMT   37.177685   37.286317   36.792809   37.003872
#
#           volume  day      macd     boll_ub     boll_lb     rsi_30     cci_30  \
# 2892   2932900.0  1.0 -0.018501  288.644682  257.612908  52.413036 -20.026804
# 2892   9040100.0  1.0  1.025072  194.257232  180.858008  53.021017 -51.428970
# 2892  17414800.0  1.0 -0.352851   43.524875   39.336046  48.097046 -50.671315
# 2892   4782100.0  1.0 -0.070741   35.890249   30.733455  48.830187 -14.266622
# 2892  20509200.0  1.0 -0.283846   38.250865   36.341645  48.159659 -69.838905
#
#          dx_30  close_30_sma  close_60_sma    vix  turbulence
# 2892  0.598862    273.539193    266.872868  30.43   12.918632
# 2892  2.103724    187.155981    177.570353  30.43   12.918632
# 2892  8.321291     41.178803     41.544123  30.43   12.918632
# 2892  0.948752     32.963969     32.795456  30.43   12.918632
# 2892  3.557607     37.711030     38.330749  30.43   12.918632

# %%
trade.head()
# Out:
#          date   tic       close        high         low        open  \
# 0  2020-07-01  AAPL   88.485016   89.274822   88.436417   88.730466
# 0  2020-07-01  AMGN  218.336411  219.286383  199.046267  201.562376
# 0  2020-07-01   AXP   88.271126   91.002318   87.886315   89.397389
# 0  2020-07-01    BA  180.320007  190.610001  180.039993  185.880005
# 0  2020-07-01   CAT  113.409096  116.413903  113.247160  116.395920
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  2.967005   91.235601   78.913914  62.807188  107.472280
# 0    6575800.0  2.0  3.306031  211.284535  182.023969  61.279637  272.795129
# 0    3301000.0  2.0 -0.373038  105.848934   84.123358  48.504817  -62.638297
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.196233  122.783119  106.548715  52.865409   35.366092
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.811448     82.608455     76.490383  28.620001   53.068269
# 0  47.010072    195.339146    196.314670  28.620001   53.068269
# 0   1.752099     93.215670     86.937895  28.620001   53.068269
# 0  15.936440    176.472335    155.614168  28.620001   53.068269
# 0  14.542117    112.244676    106.824648  28.620001   53.068269

# %%
INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for Training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
env_train = DummyVecEnv([lambda: e_train_gym])
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**. Users are also encouraged to try **ElegantRL** and **Ray RLlib**.
# * FinRL includes fine-tuned standard DRL algorithms, such as DQN, DDPG, Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
agent = DRLAgent(env = env_train)

if_using_a2c = True
if_using_ddpg = True
if_using_ppo = True
if_using_td3 = True
if_using_sac = True

# %% [markdown]
# ### Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Agent 3: PPO

# %%
from stable_baselines3.common.vec_env import DummyVecEnv

policy_kwargs = dict(
    features_extractor_class=TransformerFeatureExtractor,
    features_extractor_kwargs=dict(
        d_model=32,     # ✅ Smaller embedding
        nhead=2,        # ✅ Fewer attention heads
        num_layers=1    # ✅ Only 1 transformer block
    ),
    net_arch=dict(pi=[64, 64], vf=[64, 64])
)

model = PPO(
    policy="MlpPolicy",
    env=env_train,
    policy_kwargs=policy_kwargs,
    verbose=1,
    tensorboard_log="./tensorboard/ppo_transformer/",
    learning_rate=3e-4,
    device="cuda",
    n_steps=512,        # ✅ Reduced rollout length (default is 2048)
    batch_size=64,      # ✅ Reasonable batch size
    max_grad_norm=0.5   # ✅ Gradient clipping for stability
)

import torch
torch.cuda.empty_cache()
# Out:
# Using cuda device
# c:\Users\jvija\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(

# %%
trained_ppo = model.learn(total_timesteps=200000)
model.save("ppo_transformer_trader")
# Out:
# Logging to ./tensorboard/ppo_transformer/PPO_5
# ----------------------------
# | time/              |     |
# |    fps             | 54  |
# |    iterations      | 1   |
# |    time_elapsed    | 9   |
# |    total_timesteps | 512 |
# ----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 2           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.017092783 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.00633    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.92        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0242     |
# |    std                  | 1           |
# |    value_loss           | 3.91        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 3           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.013157094 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.000692   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.84        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 1           |
# |    value_loss           | 11          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 4           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.013257634 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.0589      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.96        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.999       |
# |    value_loss           | 8.99        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 5           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.020140171 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | -0.0312     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0273     |
# |    std                  | 0.999       |
# |    value_loss           | 31.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 6           |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.015726086 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | -0.0217     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.9        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00614    |
# |    std                  | 0.999       |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 7           |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.026814373 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | -0.0289     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 90.9        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.0108      |
# |    std                  | 0.999       |
# |    value_loss           | 360         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 8           |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.022784766 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | -0.495      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.3         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.999       |
# |    value_loss           | 8.09        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 46         |
# |    iterations           | 9          |
# |    time_elapsed         | 98         |
# |    total_timesteps      | 4608       |
# | train/                  |            |
# |    approx_kl            | 0.02126358 |
# |    clip_fraction        | 0.244      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.1      |
# |    explained_variance   | 0.068      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.1        |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0286    |
# |    std                  | 0.999      |
# |    value_loss           | 7.82       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 10          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.021611547 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.0287      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.999       |
# |    value_loss           | 24.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 45         |
# |    iterations           | 11         |
# |    time_elapsed         | 124        |
# |    total_timesteps      | 5632       |
# | train/                  |            |
# |    approx_kl            | 0.08423047 |
# |    clip_fraction        | 0.505      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.1      |
# |    explained_variance   | -0.267     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.3       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00396   |
# |    std                  | 1          |
# |    value_loss           | 39.5       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 12         |
# |    time_elapsed         | 136        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.03334901 |
# |    clip_fraction        | 0.27       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | -0.0196    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 161        |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0016    |
# |    std                  | 1          |
# |    value_loss           | 297        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 13         |
# |    time_elapsed         | 148        |
# |    total_timesteps      | 6656       |
# | train/                  |            |
# |    approx_kl            | 0.04401335 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | -0.0776    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 187        |
# |    n_updates            | 120        |
# |    policy_gradient_loss | 0.0111     |
# |    std                  | 1          |
# |    value_loss           | 460        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 14          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.019971149 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.358      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.62        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 1           |
# |    value_loss           | 9.39        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 15          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.014524667 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.77        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 1           |
# |    value_loss           | 8.03        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 16          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013515261 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.85        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 1           |
# |    value_loss           | 22          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 17          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 8704        |
# | train/                  |             |
# |    approx_kl            | 0.012722703 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.197       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.4        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.0082      |
# |    std                  | 1           |
# |    value_loss           | 35.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 50         |
# |    iterations           | 18         |
# |    time_elapsed         | 182        |
# |    total_timesteps      | 9216       |
# | train/                  |            |
# |    approx_kl            | 0.02133889 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | 0.0948     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 94.5       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | 0.00696    |
# |    std                  | 1          |
# |    value_loss           | 285        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 51          |
# |    iterations           | 19          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.032389276 |
# |    clip_fraction        | 0.338       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.447      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.42        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 1           |
# |    value_loss           | 7.45        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 53         |
# |    iterations           | 20         |
# |    time_elapsed         | 191        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01845193 |
# |    clip_fraction        | 0.22       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | 0.116      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.2        |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.02      |
# |    std                  | 1          |
# |    value_loss           | 12.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 21          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 10752       |
# | train/                  |             |
# |    approx_kl            | 0.019126207 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.13        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.18        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 1           |
# |    value_loss           | 9.7         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 22          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.022225505 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.224      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.9        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 1           |
# |    value_loss           | 24.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 23          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 11776       |
# | train/                  |             |
# |    approx_kl            | 0.028527694 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.661      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.4        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00345     |
# |    std                  | 1           |
# |    value_loss           | 34.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 24         |
# |    time_elapsed         | 208        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01531665 |
# |    clip_fraction        | 0.0871     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | 0.0754     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 65.7       |
# |    n_updates            | 230        |
# |    policy_gradient_loss | 0.0138     |
# |    std                  | 1          |
# |    value_loss           | 126        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 25          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.022320181 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.161      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.05        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0203     |
# |    std                  | 1           |
# |    value_loss           | 13.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 26          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.025921099 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.407      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.05        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 1           |
# |    value_loss           | 7.02        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 27          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 13824       |
# | train/                  |             |
# |    approx_kl            | 0.025633419 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.65        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0238     |
# |    std                  | 1           |
# |    value_loss           | 19.9        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 63         |
# |    iterations           | 28         |
# |    time_elapsed         | 225        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.02848373 |
# |    clip_fraction        | 0.281      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | -0.679     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.95       |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.00149   |
# |    std                  | 1          |
# |    value_loss           | 20         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 29          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 14848       |
# | train/                  |             |
# |    approx_kl            | 0.033469126 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0516     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.4        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00754    |
# |    std                  | 1           |
# |    value_loss           | 64.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 65         |
# |    iterations           | 30         |
# |    time_elapsed         | 233        |
# |    total_timesteps      | 15360      |
# | train/                  |            |
# |    approx_kl            | 0.03131963 |
# |    clip_fraction        | 0.149      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | 0.11       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 57.7       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | 0.0103     |
# |    std                  | 1          |
# |    value_loss           | 118        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 66          |
# |    iterations           | 31          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 15872       |
# | train/                  |             |
# |    approx_kl            | 0.015423545 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | -0.148      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.32        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0161     |
# |    std                  | 0.999       |
# |    value_loss           | 10.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 32          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.020064104 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.233       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.7         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.021      |
# |    std                  | 0.999       |
# |    value_loss           | 9.78        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 33          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 16896       |
# | train/                  |             |
# |    approx_kl            | 0.018940013 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14          |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.999       |
# |    value_loss           | 30.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 34          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.017819993 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.0341      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.8        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0098     |
# |    std                  | 0.998       |
# |    value_loss           | 38.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 35         |
# |    time_elapsed         | 255        |
# |    total_timesteps      | 17920      |
# | train/                  |            |
# |    approx_kl            | 0.04922028 |
# |    clip_fraction        | 0.469      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.1      |
# |    explained_variance   | 0.168      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 117        |
# |    n_updates            | 340        |
# |    policy_gradient_loss | 0.0548     |
# |    std                  | 0.998      |
# |    value_loss           | 209        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 36          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.022205891 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.519       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.81        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0282     |
# |    std                  | 0.998       |
# |    value_loss           | 6.05        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 37          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 18944       |
# | train/                  |             |
# |    approx_kl            | 0.022985317 |
# |    clip_fraction        | 0.34        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | -0.0867     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.53        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.997       |
# |    value_loss           | 17.5        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 72        |
# |    iterations           | 38        |
# |    time_elapsed         | 267       |
# |    total_timesteps      | 19456     |
# | train/                  |           |
# |    approx_kl            | 0.0217973 |
# |    clip_fraction        | 0.244     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -41       |
# |    explained_variance   | 0.306     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.11      |
# |    n_updates            | 370       |
# |    policy_gradient_loss | -0.0174   |
# |    std                  | 0.996     |
# |    value_loss           | 14.8      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 39          |
# |    time_elapsed         | 271         |
# |    total_timesteps      | 19968       |
# | train/                  |             |
# |    approx_kl            | 0.025089778 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41         |
# |    explained_variance   | 0.0967      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.8        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.995       |
# |    value_loss           | 45.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 40          |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.036784302 |
# |    clip_fraction        | 0.441       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41         |
# |    explained_variance   | 0.115       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.9        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.0521      |
# |    std                  | 0.995       |
# |    value_loss           | 107         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 41          |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 20992       |
# | train/                  |             |
# |    approx_kl            | 0.031639986 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41         |
# |    explained_variance   | 0.215       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.8        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00737     |
# |    std                  | 0.995       |
# |    value_loss           | 282         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 75          |
# |    iterations           | 42          |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.030469174 |
# |    clip_fraction        | 0.328       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41         |
# |    explained_variance   | -0.0548     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.62        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 0.994       |
# |    value_loss           | 9.62        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 76          |
# |    iterations           | 43          |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 22016       |
# | train/                  |             |
# |    approx_kl            | 0.029163733 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41         |
# |    explained_variance   | -0.255      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.15        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0207     |
# |    std                  | 0.996       |
# |    value_loss           | 8.25        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 76         |
# |    iterations           | 44         |
# |    time_elapsed         | 292        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.02649011 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41        |
# |    explained_variance   | 0.429      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.02       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0097    |
# |    std                  | 0.997      |
# |    value_loss           | 15.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 77          |
# |    iterations           | 45          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 23040       |
# | train/                  |             |
# |    approx_kl            | 0.019865159 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.0861      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.3        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00952    |
# |    std                  | 0.997       |
# |    value_loss           | 23.1        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 78         |
# |    iterations           | 46         |
# |    time_elapsed         | 301        |
# |    total_timesteps      | 23552      |
# | train/                  |            |
# |    approx_kl            | 0.04396903 |
# |    clip_fraction        | 0.437      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.1      |
# |    explained_variance   | 0.245      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 36.8       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.0415     |
# |    std                  | 0.997      |
# |    value_loss           | 82         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 47          |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 24064       |
# | train/                  |             |
# |    approx_kl            | 0.024473052 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.34        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.9        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00139     |
# |    std                  | 0.997       |
# |    value_loss           | 139         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 48          |
# |    time_elapsed         | 309         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.026173446 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.153       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.67        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0241     |
# |    std                  | 0.997       |
# |    value_loss           | 14.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 49          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 25088       |
# | train/                  |             |
# |    approx_kl            | 0.017174264 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.453       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.44        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0211     |
# |    std                  | 0.997       |
# |    value_loss           | 7.34        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 50          |
# |    time_elapsed         | 317         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.020731397 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.89        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0234     |
# |    std                  | 0.998       |
# |    value_loss           | 17.7        |
# -----------------------------------------
# day: 2892, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5055963.20
# total_reward: 4055963.20
# total_cost: 179690.37
# total_trades: 68223
# Sharpe: 0.878
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 51          |
# |    time_elapsed         | 322         |
# |    total_timesteps      | 26112       |
# | train/                  |             |
# |    approx_kl            | 0.020739384 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.6        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.0233      |
# |    std                  | 0.998       |
# |    value_loss           | 50.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 81          |
# |    iterations           | 52          |
# |    time_elapsed         | 326         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.040951066 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.359       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.7        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00575     |
# |    std                  | 0.998       |
# |    value_loss           | 170         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 53         |
# |    time_elapsed         | 330        |
# |    total_timesteps      | 27136      |
# | train/                  |            |
# |    approx_kl            | 0.02287921 |
# |    clip_fraction        | 0.245      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.1      |
# |    explained_variance   | 0.256      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.43       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.015     |
# |    std                  | 0.999      |
# |    value_loss           | 7.29       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 54          |
# |    time_elapsed         | 335         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.025223987 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.175       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.46        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0216     |
# |    std                  | 0.999       |
# |    value_loss           | 16.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 82         |
# |    iterations           | 55         |
# |    time_elapsed         | 339        |
# |    total_timesteps      | 28160      |
# | train/                  |            |
# |    approx_kl            | 0.01953878 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.1      |
# |    explained_variance   | 0.475      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.21       |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.0199    |
# |    std                  | 0.999      |
# |    value_loss           | 10.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 56          |
# |    time_elapsed         | 344         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.020559195 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.59        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00861    |
# |    std                  | 0.999       |
# |    value_loss           | 17.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 57          |
# |    time_elapsed         | 348         |
# |    total_timesteps      | 29184       |
# | train/                  |             |
# |    approx_kl            | 0.039559335 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.38        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.3        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | 0.00902     |
# |    std                  | 0.999       |
# |    value_loss           | 81.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 58          |
# |    time_elapsed         | 353         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.034451965 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.568       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.8        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | 0.016       |
# |    std                  | 0.999       |
# |    value_loss           | 121         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 59          |
# |    time_elapsed         | 357         |
# |    total_timesteps      | 30208       |
# | train/                  |             |
# |    approx_kl            | 0.021754239 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.43        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.998       |
# |    value_loss           | 15.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 60          |
# |    time_elapsed         | 361         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.024863226 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.381       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.72        |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.998       |
# |    value_loss           | 12.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 61          |
# |    time_elapsed         | 366         |
# |    total_timesteps      | 31232       |
# | train/                  |             |
# |    approx_kl            | 0.025582481 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.458       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.42        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 0.999       |
# |    value_loss           | 16.7        |
# ...
# |    n_updates            | 770         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.999       |
# |    value_loss           | 19.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 79          |
# |    time_elapsed         | 442         |
# |    total_timesteps      | 40448       |
# | train/                  |             |
# |    approx_kl            | 0.031083584 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.5        |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.00799    |
# |    std                  | 0.999       |
# |    value_loss           | 29.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 91         |
# |    iterations           | 80         |
# |    time_elapsed         | 447        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.16758597 |
# |    clip_fraction        | 0.586      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.1      |
# |    explained_variance   | 0.366      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 67         |
# |    n_updates            | 790        |
# |    policy_gradient_loss | 0.112      |
# |    std                  | 0.999      |
# |    value_loss           | 153        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 81          |
# |    time_elapsed         | 451         |
# |    total_timesteps      | 41472       |
# | train/                  |             |
# |    approx_kl            | 0.017861586 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0.713       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.34        |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.000872   |
# |    std                  | 0.999       |
# |    value_loss           | 8.9         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 92         |
# |    iterations           | 82         |
# |    time_elapsed         | 455        |
# |    total_timesteps      | 41984      |
# | train/                  |            |
# |    approx_kl            | 0.02126458 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.1      |
# |    explained_variance   | 0.568      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.14       |
# |    n_updates            | 810        |
# |    policy_gradient_loss | -0.0228    |
# |    std                  | 1          |
# |    value_loss           | 9.22       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 83          |
# |    time_elapsed         | 460         |
# |    total_timesteps      | 42496       |
# | train/                  |             |
# |    approx_kl            | 0.018939227 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.438       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.95        |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 1           |
# |    value_loss           | 8           |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 92         |
# |    iterations           | 84         |
# |    time_elapsed         | 464        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.02547764 |
# |    clip_fraction        | 0.327      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | 0.758      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.78       |
# |    n_updates            | 830        |
# |    policy_gradient_loss | -0.00629   |
# |    std                  | 1          |
# |    value_loss           | 12.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 85          |
# |    time_elapsed         | 468         |
# |    total_timesteps      | 43520       |
# | train/                  |             |
# |    approx_kl            | 0.015389825 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.435       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.5        |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00781    |
# |    std                  | 1           |
# |    value_loss           | 43.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 86          |
# |    time_elapsed         | 473         |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.023657065 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.572       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.6        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | 0.00618     |
# |    std                  | 1           |
# |    value_loss           | 89          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 87          |
# |    time_elapsed         | 477         |
# |    total_timesteps      | 44544       |
# | train/                  |             |
# |    approx_kl            | 0.024391808 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.00904    |
# |    std                  | 1           |
# |    value_loss           | 5.83        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 88          |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.020396452 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.77        |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 1           |
# |    value_loss           | 7.87        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 89          |
# |    time_elapsed         | 485         |
# |    total_timesteps      | 45568       |
# | train/                  |             |
# |    approx_kl            | 0.021639716 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.12        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 1           |
# |    value_loss           | 7.81        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 93         |
# |    iterations           | 90         |
# |    time_elapsed         | 490        |
# |    total_timesteps      | 46080      |
# | train/                  |            |
# |    approx_kl            | 0.03746696 |
# |    clip_fraction        | 0.362      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | 0.445      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.25       |
# |    n_updates            | 890        |
# |    policy_gradient_loss | -0.0275    |
# |    std                  | 1          |
# |    value_loss           | 15.4       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 91         |
# |    time_elapsed         | 494        |
# |    total_timesteps      | 46592      |
# | train/                  |            |
# |    approx_kl            | 0.02488197 |
# |    clip_fraction        | 0.305      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | 0.649      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 40.2       |
# |    n_updates            | 900        |
# |    policy_gradient_loss | 0.0187     |
# |    std                  | 1          |
# |    value_loss           | 85.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 92          |
# |    time_elapsed         | 499         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.026705906 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.535       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75.3        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | 0.00946     |
# |    std                  | 1           |
# |    value_loss           | 128         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 93          |
# |    time_elapsed         | 503         |
# |    total_timesteps      | 47616       |
# | train/                  |             |
# |    approx_kl            | 0.027369887 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.714       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.07        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0247     |
# |    std                  | 1           |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 94          |
# |    time_elapsed         | 507         |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.031871118 |
# |    clip_fraction        | 0.344       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.155      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.83        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.00501    |
# |    std                  | 1           |
# |    value_loss           | 9.06        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 94        |
# |    iterations           | 95        |
# |    time_elapsed         | 512       |
# |    total_timesteps      | 48640     |
# | train/                  |           |
# |    approx_kl            | 0.0285148 |
# |    clip_fraction        | 0.327     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -41.2     |
# |    explained_variance   | 0.614     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 6.3       |
# |    n_updates            | 940       |
# |    policy_gradient_loss | -0.0166   |
# |    std                  | 1         |
# |    value_loss           | 13.6      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 96         |
# |    time_elapsed         | 516        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.04080634 |
# |    clip_fraction        | 0.346      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | 0.456      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 19.2       |
# |    n_updates            | 950        |
# |    policy_gradient_loss | -0.0114    |
# |    std                  | 1          |
# |    value_loss           | 55.6       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 97          |
# |    time_elapsed         | 521         |
# |    total_timesteps      | 49664       |
# | train/                  |             |
# |    approx_kl            | 0.079814434 |
# |    clip_fraction        | 0.428       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.486       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 103         |
# |    n_updates            | 960         |
# |    policy_gradient_loss | 0.0253      |
# |    std                  | 1           |
# |    value_loss           | 203         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 98         |
# |    time_elapsed         | 525        |
# |    total_timesteps      | 50176      |
# | train/                  |            |
# |    approx_kl            | 0.04090812 |
# |    clip_fraction        | 0.413      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | 0.6        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.1        |
# |    n_updates            | 970        |
# |    policy_gradient_loss | 0.00312    |
# |    std                  | 1          |
# |    value_loss           | 11.7       |
# ----------------------------------------

# %%
trained_model = trained_ppo

# %% [markdown]
# ## In-sample Performance
#
# Assume that the initial capital is $1,000,000.

# %% [markdown]
# ### Set turbulence threshold
# Set the turbulence threshold to be greater than the maximum of insample turbulence data. If current turbulence index is greater than the threshold, then we assume that the current market is volatile

# %%
data_risk_indicator = processed_full[(processed_full.date<TRAIN_END_DATE) & (processed_full.date>=TRAIN_START_DATE)]
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])

# %%
insample_risk_indicator.vix.describe()
# Out:
# count    2893.000000
# mean       18.824245
# std         8.489311
# min         9.140000
# 25%        13.330000
# 50%        16.139999
# 75%        21.309999
# max        82.690002
# Name: vix, dtype: float64

# %%
insample_risk_indicator.vix.quantile(0.996)
# Out:
# 57.40400183105453

# %%
insample_risk_indicator.turbulence.describe()
# Out:
# count    2893.000000
# mean       34.567957
# std        43.790793
# min         0.000000
# 25%        14.962670
# 50%        24.124061
# 75%        39.162682
# max       652.505172
# Name: turbulence, dtype: float64

# %%
insample_risk_indicator.turbulence.quantile(0.996)
# Out:
# 276.4522083965639

# %% [markdown]
# ### Trading (Out-of-sample Performance)
#
# We update periodically in order to take full advantage of the data, e.g., retrain quarterly, monthly or weekly. We also tune the parameters along the way, in this notebook we use the in-sample data from 2009-01 to 2020-07 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 55,risk_indicator_col='vix', **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
trade.head()
# Out:
#          date   tic       close        high         low        open  \
# 0  2020-07-01  AAPL   88.485016   89.274822   88.436417   88.730466
# 0  2020-07-01  AMGN  218.336411  219.286383  199.046267  201.562376
# 0  2020-07-01   AXP   88.271126   91.002318   87.886315   89.397389
# 0  2020-07-01    BA  180.320007  190.610001  180.039993  185.880005
# 0  2020-07-01   CAT  113.409096  116.413903  113.247160  116.395920
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  2.967005   91.235601   78.913914  62.807188  107.472280
# 0    6575800.0  2.0  3.306031  211.284535  182.023969  61.279637  272.795129
# 0    3301000.0  2.0 -0.373038  105.848934   84.123358  48.504817  -62.638297
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.196233  122.783119  106.548715  52.865409   35.366092
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.811448     82.608455     76.490383  28.620001   53.068269
# 0  47.010072    195.339146    196.314670  28.620001   53.068269
# 0   1.752099     93.215670     86.937895  28.620001   53.068269
# 0  15.936440    176.472335    155.614168  28.620001   53.068269
# 0  14.542117    112.244676    106.824648  28.620001   53.068269

# %%
# Reset the environment
obs = e_trade_gym.reset()
if isinstance(obs, tuple):  # Gymnasium compatibility
    obs = obs[0]

done = False
account_memory = []
actions_memory = []

while not done:
    action, _states = trained_model.predict(obs, deterministic=True)

    obs, reward, done, truncated, info = e_trade_gym.step(action)

    # Save current account value and action
    account_memory.append(e_trade_gym.asset_memory[-1])
    actions_memory.append(e_trade_gym.actions_memory[-1])

# Build DataFrames
df_account_value_transformer = pd.DataFrame(account_memory, columns=["account_value"])
df_actions_transformer = pd.DataFrame(actions_memory)

# Optional: Save to disk
df_account_value_transformer.to_csv("account_value_transformer.csv", index=False)
df_actions_transformer.to_csv("actions_transformer.csv", index=False)

print("✅ Transformer-PPO trading completed.")
# Out:
# ✅ Transformer-PPO trading completed.

# %% [markdown]
# <a id='7'></a>
# # Part 6.5: Mean Variance Optimization

# %% [markdown]
# Mean Variance optimization is a very classic strategy in portfolio management. Here, we go through the whole process to do the mean variance optimization and add it as a baseline to compare.
#
# First, process dataframe to the form for MVO weight calculation.

# %%
def process_df_for_mvo(df):
  df = df.sort_values(['date','tic'],ignore_index=True)[['date','tic','close']]
  fst = df
  fst = fst.iloc[0:stock_dimension, :]
  tic = fst['tic'].tolist()

  mvo = pd.DataFrame()

  for k in range(len(tic)):
    mvo[tic[k]] = 0

  for i in range(df.shape[0]//stock_dimension):
    n = df
    n = n.iloc[i * stock_dimension:(i+1) * stock_dimension, :]
    date = n['date'][i*stock_dimension]
    mvo.loc[date] = n['close'].tolist()

  return mvo

# %% [markdown]
# ### Helper functions for mean returns and variance-covariance matrix

# %%
# Codes in this section partially refer to Dr G A Vijayalakshmi Pai

# https://www.kaggle.com/code/vijipai/lesson-5-mean-variance-optimization-of-portfolios/notebook

def StockReturnsComputing(StockPrice, Rows, Columns):
  import numpy as np
  StockReturn = np.zeros([Rows-1, Columns])
  for j in range(Columns):        # j: Assets
    for i in range(Rows-1):     # i: Daily Prices
      StockReturn[i,j]=((StockPrice[i+1, j]-StockPrice[i,j])/StockPrice[i,j])* 100

  return StockReturn

# %% [markdown]
# ### Calculate the weights for mean-variance

# %%
train_mvo = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE).reset_index()
trade_mvo = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE).reset_index()

# %%
StockData = process_df_for_mvo(train_mvo)
TradeData = process_df_for_mvo(trade_mvo)

TradeData.to_numpy()
# Out:
# array([[ 88.485, 218.336,  88.271, ...,  40.327,  31.709,  37.15 ],
#        [ 88.485, 221.007,  88.534, ...,  40.415,  32.562,  37.001],
#        [ 90.852, 219.303,  90.646, ...,  40.747,  33.477,  36.901],
#        ...,
#        [145.68 , 184.125, 173.826, ...,  41.435,  40.18 ,  47.494],
#        [146.346, 185.056, 172.529, ...,  41.829,  39.437,  47.079],
#        [145.886, 183.194, 169.745, ...,  41.474,  38.465,  46.693]])

# %%
#compute asset returns
arStockPrices = np.asarray(StockData)
[Rows, Cols]=arStockPrices.shape
arReturns = StockReturnsComputing(arStockPrices, Rows, Cols)

#compute mean returns and variance covariance matrix of returns
meanReturns = np.mean(arReturns, axis = 0)
covReturns = np.cov(arReturns, rowvar=False)

#set precision for printing results
np.set_printoptions(precision=3, suppress = True)

#display mean returns and variance-covariance matrix of returns
print('Mean returns of assets in k-portfolio 1\n', meanReturns)
print('Variance-Covariance matrix of returns\n', covReturns)
# Out:
# Mean returns of assets in k-portfolio 1
#  [0.136 0.068 0.086 0.083 0.066 0.134 0.06  0.035 0.072 0.056 0.103 0.073
#  0.033 0.076 0.047 0.073 0.042 0.056 0.054 0.056 0.103 0.089 0.041 0.053
#  0.104 0.11  0.044 0.042 0.042]
# Variance-Covariance matrix of returns
#  [[3.156 1.066 1.768 1.669 1.722 1.814 1.569 1.302 1.302 1.811 1.303 1.432
#   1.218 1.674 0.74  1.839 0.719 0.884 1.241 0.823 1.561 1.324 0.752 1.027
#   1.298 1.466 0.657 1.078 0.631]
#  [1.066 2.571 1.306 1.123 1.193 1.319 1.116 1.053 1.045 1.269 1.068 1.089
#   0.899 1.218 0.926 1.391 0.682 0.727 1.025 1.156 1.166 0.984 0.798 0.956
#   1.259 1.111 0.688 1.091 0.682]
#  [1.768 1.306 4.847 2.73  2.6   2.128 1.944 2.141 2.17  3.142 1.932 2.283
#   1.56  2.012 0.993 3.707 1.094 1.319 1.845 1.236 1.899 1.894 1.041 1.921
#   1.823 2.314 0.986 1.421 0.707]
#  [1.669 1.123 2.73  4.892 2.363 1.979 1.7   2.115 1.959 2.387 1.773 2.319
#   1.571 1.797 0.968 2.597 1.144 1.298 1.643 1.071 1.615 1.775 0.91  1.666
#   1.707 1.784 0.82  1.345 0.647]
#  [1.722 1.193 2.6   2.363 4.019 2.127 1.917 2.059 1.817 2.46  1.577 2.238
#   1.513 1.929 0.925 2.64  0.947 0.971 1.894 1.089 1.711 1.642 0.865 1.456
#   1.478 1.687 0.92  1.326 0.697]
#  [1.814 1.319 2.128 1.979 2.127 5.384 1.974 1.549 1.683 2.122 1.624 1.771
#   1.441 1.939 0.846 2.191 0.837 1.075 1.475 1.041 1.978 1.768 0.784 1.328
#   1.365 1.912 0.787 1.28  0.666]
#  [1.569 1.116 1.944 1.7   1.917 1.974 3.081 1.483 1.534 1.937 1.367 1.62
#   1.399 1.843 0.894 2.057 0.794 0.905 1.438 1.014 1.72  1.382 0.865 1.206
#   1.273 1.488 0.811 1.173 0.753]
#  [1.302 1.053 2.141 2.115 2.059 1.549 1.483 2.842 1.525 2.044 1.428 1.783
#   1.308 1.533 0.878 2.279 0.938 1.092 1.385 1.078 1.429 1.314 0.831 1.459
#   1.466 1.48  0.83  1.042 0.567]
#  [1.302 1.045 2.17  1.959 1.817 1.683 1.534 1.525 2.661 1.987 1.454 1.748
#   1.217 1.475 0.791 2.216 0.896 0.973 1.396 0.949 1.379 1.407 0.859 1.268
#   1.281 1.454 0.81  1.143 0.667]
#  [1.811 1.269 3.142 2.387 2.46  2.122 1.937 2.044 1.987 4.407 1.789 2.12
#   1.593 1.982 0.945 3.96  0.956 1.094 1.758 1.157 1.788 1.692 0.905 1.879
#   1.712 2.    0.945 1.421 0.713]
#  [1.303 1.068 1.932 1.773 1.577 1.624 1.367 1.428 1.454 1.789 2.373 1.51
#   1.166 1.501 0.756 1.941 0.824 0.998 1.239 0.887 1.366 1.414 0.797 1.299
#   1.296 1.41  0.764 1.071 0.783]
#  [1.432 1.089 2.283 2.319 2.238 1.771 1.62  1.783 1.748 2.12  1.51  2.517
#   1.326 1.575 0.889 2.345 0.958 1.022 1.623 1.02  1.489 1.532 0.848 1.377
#   1.444 1.547 0.81  1.211 0.63 ]
#  [1.218 0.899 1.56  1.571 1.513 1.441 1.399 1.308 1.217 1.593 1.166 1.326
#   2.052 1.399 0.727 1.749 0.786 0.795 1.154 0.829 1.296 1.12  0.743 1.105
#   1.088 1.214 0.739 0.998 0.598]
#  [1.674 1.218 2.012 1.797 1.929 1.939 1.843 1.533 1.475 1.982 1.501 1.575
#   1.399 3.289 0.853 2.112 0.85  0.89  1.412 1.002 1.9   1.352 0.842 1.317
#   1.334 1.487 0.847 1.165 0.766]
#  [0.74  0.926 0.993 0.968 0.925 0.846 0.894 0.878 0.791 0.945 0.756 0.889
#   0.727 0.853 1.153 1.027 0.642 0.59  0.848 0.892 0.825 0.748 0.694 0.761
#   0.929 0.819 0.61  0.806 0.547]
#  [1.839 1.391 3.707 2.597 2.64  2.191 2.057 2.279 2.216 3.96  1.941 2.345
#   1.749 2.112 1.027 5.271 1.08  1.235 1.892 1.297 1.91  1.85  1.068 2.164
#   1.85  2.169 1.112 1.555 0.779]
#  [0.719 0.682 1.094 1.144 0.947 0.837 0.794 0.938 0.896 0.956 0.824 0.958
#   0.786 0.85  0.642 1.08  1.264 0.679 0.804 0.74  0.819 0.845 0.749 0.891
#   0.849 0.794 0.633 0.719 0.514]
#  [0.884 0.727 1.319 1.298 0.971 1.075 0.905 1.092 0.973 1.094 0.998 1.022
#   0.795 0.89  0.59  1.235 0.679 1.518 0.816 0.719 0.943 1.027 0.615 1.
#   0.947 0.994 0.533 0.673 0.504]
#  [1.241 1.025 1.845 1.643 1.894 1.475 1.438 1.385 1.396 1.758 1.239 1.623
#   1.154 1.412 0.848 1.892 0.804 0.816 2.028 0.9   1.265 1.243 0.787 1.194
#   1.193 1.282 0.752 1.099 0.622]
#  [0.823 1.156 1.236 1.071 1.089 1.041 1.014 1.078 0.949 1.157 0.887 1.02
#   0.829 1.002 0.892 1.297 0.74  0.719 0.9   2.007 0.952 0.849 0.732 1.008
#   1.15  0.933 0.722 0.897 0.614]
#  [1.561 1.166 1.899 1.615 1.711 1.978 1.72  1.429 1.379 1.788 1.366 1.489
#   1.296 1.9   0.825 1.91  0.819 0.943 1.265 0.952 2.759 1.308 0.832 1.214
#   1.285 1.493 0.793 1.113 0.705]
#  [1.324 0.984 1.894 1.775 1.642 1.768 1.382 1.314 1.407 1.692 1.414 1.532
#   1.12  1.352 0.748 1.85  0.845 1.027 1.243 0.849 1.308 2.864 0.751 1.153
#   1.26  1.411 0.71  1.046 0.651]
#  [0.752 0.798 1.041 0.91  0.865 0.784 0.865 0.831 0.859 0.905 0.797 0.848
#   0.743 0.842 0.694 1.068 0.749 0.615 0.787 0.732 0.832 0.751 1.289 0.806
#   0.766 0.763 0.663 0.797 0.645]
#  [1.027 0.956 1.921 1.666 1.456 1.328 1.206 1.459 1.268 1.879 1.299 1.377
#   1.105 1.317 0.761 2.164 0.891 1.    1.194 1.008 1.214 1.153 0.806 2.27
#   1.259 1.294 0.812 0.986 0.676]
#  [1.298 1.259 1.823 1.707 1.478 1.365 1.273 1.466 1.281 1.712 1.296 1.444
#   1.088 1.334 0.929 1.85  0.849 0.947 1.193 1.15  1.285 1.26  0.766 1.259
#   3.352 1.267 0.697 1.137 0.685]
#  [1.466 1.111 2.314 1.784 1.687 1.912 1.488 1.48  1.454 2.    1.41  1.547
#   1.214 1.487 0.819 2.169 0.794 0.994 1.282 0.933 1.493 1.411 0.763 1.294
#   1.267 2.982 0.709 1.007 0.656]
#  [0.657 0.688 0.986 0.82  0.92  0.787 0.811 0.83  0.81  0.945 0.764 0.81
#   0.739 0.847 0.61  1.112 0.633 0.533 0.752 0.722 0.793 0.71  0.663 0.812
#   0.697 0.709 1.371 0.697 0.561]
#  [1.078 1.091 1.421 1.345 1.326 1.28  1.173 1.042 1.143 1.421 1.071 1.211
#   0.998 1.165 0.806 1.555 0.719 0.673 1.099 0.897 1.113 1.046 0.797 0.986
#   1.137 1.007 0.697 3.073 0.759]
#  [0.631 0.682 0.707 0.647 0.697 0.666 0.753 0.567 0.667 0.713 0.783 0.63
#   0.598 0.766 0.547 0.779 0.514 0.504 0.622 0.614 0.705 0.651 0.645 0.676
#   0.685 0.656 0.561 0.759 1.452]]

# %% [markdown]
# ### Use PyPortfolioOpt

# %%
from pypfopt.efficient_frontier import EfficientFrontier

ef_mean = EfficientFrontier(meanReturns, covReturns, weight_bounds=(0, 0.5))
raw_weights_mean = ef_mean.max_sharpe()
cleaned_weights_mean = ef_mean.clean_weights()
mvo_weights = np.array([1000000 * cleaned_weights_mean[i] for i in range(29)])
mvo_weights
# Out:
# array([375410.,      0.,      0.,      0.,      0.,  85810.,      0.,
#             0.,      0.,      0., 205910.,      0.,      0.,      0.,
#             0.,      0.,      0.,      0.,      0.,      0.,  49370.,
#             0.,      0.,      0., 142510., 141010.,      0.,      0.,
#             0.])

# %%
LastPrice = np.array([1/p for p in StockData.tail(1).to_numpy()[0]])
Initial_Portfolio = np.multiply(mvo_weights, LastPrice)
Initial_Portfolio
# Out:
# array([4234.615,    0.   ,    0.   ,    0.   ,    0.   ,  462.083,
#           0.   ,    0.   ,    0.   ,    0.   ,  927.12 ,    0.   ,
#           0.   ,    0.   ,    0.   ,    0.   ,    0.   ,    0.   ,
#           0.   ,    0.   ,  253.205,    0.   ,    0.   ,    0.   ,
#         521.427,  756.39 ,    0.   ,    0.   ,    0.   ])

# %%
Portfolio_Assets = TradeData @ Initial_Portfolio
MVO_result = pd.DataFrame(Portfolio_Assets, columns=["Mean Var"])
MVO_result
# Out:
#                 Mean Var
# 2020-07-01  1.001536e+06
# 2020-07-02  1.004131e+06
# 2020-07-06  1.022196e+06
# 2020-07-07  1.012411e+06
# 2020-07-08  1.027198e+06
# ...                  ...
# 2021-10-21  1.524364e+06
# 2021-10-22  1.527224e+06
# 2021-10-25  1.533949e+06
# 2021-10-26  1.537082e+06
# 2021-10-27  1.528623e+06
#
# [335 rows x 1 columns]

# %%
print("Final account value:", df_account_value_transformer['account_value'].iloc[-1])
# Out:
# Final account value: 1318164.4279552174

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtesting Results
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
# Step 1: Copy transformer PPO results
df_result_transformer = df_account_value_transformer.copy()

# Step 2: Extract unique trading dates used during rollout
unique_trade_dates = trade['date'].drop_duplicates().iloc[-len(df_result_transformer):].values

# Assign date to each row
df_result_transformer['date'] = pd.to_datetime(unique_trade_dates)
df_result_transformer.set_index('date', inplace=True)

# Rename the value column
if 'account_value' in df_result_transformer.columns:
    df_result_transformer.rename(columns={'account_value': 'transformer_ppo'}, inplace=True)

# Step 3: Prepare MVO result
MVO_result = MVO_result.copy()
MVO_result.columns = ['mean_var']
MVO_result.index = pd.to_datetime(MVO_result.index)
MVO_result.dropna(inplace=True)

# Step 4: Merge both
result = pd.merge(df_result_transformer, MVO_result, how='outer', left_index=True, right_index=True)
result.sort_index(inplace=True)

# Step 5: Save & show
result.to_csv("final_result_transformer_vs_mvo.csv")
print("✅ Final Merged Result:")
print(result.tail())
# Out:
# ✅ Final Merged Result:
#             transformer_ppo      mean_var
# date
# 2021-10-21     1.321129e+06  1.524364e+06
# 2021-10-22     1.332683e+06  1.527224e+06
# 2021-10-25     1.327589e+06  1.533949e+06
# 2021-10-26     1.318164e+06  1.537082e+06
# 2021-10-27     1.318164e+06  1.528623e+06

# %%
import matplotlib.pyplot as plt

# Ensure datetime index and no missing values in plot
plot_df = result.copy()
plot_df.dropna(subset=['transformer_ppo', 'mean_var'], how='all', inplace=True)

# Set figure size
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15, 5)

# Plot
plt.figure()
plot_df.plot(title="📈 Transformer-PPO vs MVO Portfolio Value", grid=True, ylabel="Portfolio Value ($)")
plt.xlabel("Date")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\jvija\AppData\Local\Temp\ipykernel_17264\2041585653.py:15: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\jvija\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
